# %% [markdown]
# **Data analysis** is a process of inspecting, cleansing, transforming, and modelling data with the goal of discovering useful information, informing conclusions, and supporting decision-making.

# %% [markdown]
# ![Data%20Analysis%20Data%20Extraction%20Cleaning%20and%20Data%20Wrangling%20Analysis.JPG](attachment:Data%20Analysis%20Data%20Extraction%20Cleaning%20and%20Data%20Wrangling%20Analysis.JPG)

# %% [markdown]
# ![Python%20Eco%20system%20for%20Data%20Analysis.JPG](attachment:Python%20Eco%20system%20for%20Data%20Analysis.JPG)
