# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Note: in pandas version > = 0.20.0, ix is deprecated . Thus, useloc and iloc instead.
#
# loc — gets rows (or columns) with particular labels from the index.
# iloc — gets rows (or columns) at particular positions in the index (so it only takes integers).
# ix — usually behaves like loc but falls back to behaving like iloc if a label is not present in the index.

# %%
import pandas as pd

df_titanic = pd.read_csv(r"C:\Users\DELL\Desktop\Inno_files\Material\Machine_Learning_and_Deep_Learning-master\Machine_Learning_and_Deep_Learning-master\Module 4 - Machine Learning\04. Supervised ML Algorithms\05. Logistic Regression\code\data\titanic.csv")
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic[(df_titanic['age'] >=40) & (df_titanic['age']<=50)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 30          0       1    male  40.0      0      0  27.7208        C   First
# 35          0       1    male  42.0      1      0  52.0000        S   First
# 40          0       3  female  40.0      1      0   9.4750        S   Third
# 52          1       1  female  49.0      1      0  76.7292        C   First
# 62          0       1    male  45.0      1      0  83.4750        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 860         0       3    male  41.0      2      0  14.1083        S   Third
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic[df_titanic['age'].between(40,50)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 30          0       1    male  40.0      0      0  27.7208        C   First
# 35          0       1    male  42.0      1      0  52.0000        S   First
# 40          0       3  female  40.0      1      0   9.4750        S   Third
# 52          1       1  female  49.0      1      0  76.7292        C   First
# 62          0       1    male  45.0      1      0  83.4750        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 860         0       3    male  41.0      2      0  14.1083        S   Third
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# filter people with age 42 or 47
df_titanic[(df_titanic['age']==42) | (df_titanic['age']==47)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 35          0       1    male  42.0      1      0   52.0000        S   First
# 110         0       1    male  47.0      0      0   52.0000        S   First
# 132         0       3  female  47.0      1      0   14.5000        S   Third
# 149         0       2    male  42.0      0      0   13.0000        S  Second
# 197         0       3    male  42.0      0      1    8.4042        S   Third
# 217         0       2    male  42.0      1      0   27.0000        S  Second
# 288         1       2    male  42.0      0      0   13.0000        S  Second
# 349         0       3    male  42.0      0      0    8.6625        S   Third
# 380         1       1  female  42.0      0      0  227.5250        C   First
# 432         1       2  female  42.0      1      0   26.0000        S  Second
# 462         0       1    male  47.0      0      0   38.5000        S   First
# ...

# %%
# filter people with age 42 or 47
df_titanic[df_titanic['age'].isin([42,47])]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 35          0       1    male  42.0      1      0   52.0000        S   First
# 110         0       1    male  47.0      0      0   52.0000        S   First
# 132         0       3  female  47.0      1      0   14.5000        S   Third
# 149         0       2    male  42.0      0      0   13.0000        S  Second
# 197         0       3    male  42.0      0      1    8.4042        S   Third
# 217         0       2    male  42.0      1      0   27.0000        S  Second
# 288         1       2    male  42.0      0      0   13.0000        S  Second
# 349         0       3    male  42.0      0      0    8.6625        S   Third
# 380         1       1  female  42.0      0      0  227.5250        C   First
# 432         1       2  female  42.0      1      0   26.0000        S  Second
# 462         0       1    male  47.0      0      0   38.5000        S   First
# ...

# %%
df_titanic.query('sex == "male" and age > 50')
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 33          0       2  male  66.0      0      0   10.5000        S  Second
# 54          0       1  male  65.0      0      1   61.9792        C   First
# 94          0       3  male  59.0      0      0    7.2500        S   Third
# 96          0       1  male  71.0      0      0   34.6542        C   First
# 116         0       3  male  70.5      0      0    7.7500        Q   Third
# 124         0       1  male  54.0      0      1   77.2875        S   First
# 150         0       2  male  51.0      0      0   12.5250        S  Second
# 152         0       3  male  55.5      0      0    8.0500        S   Third
# 155         0       1  male  51.0      0      1   61.3792        C   First
# 170         0       1  male  61.0      0      0   33.5000        S   First
# ...

# %%
# filter gender = male and age is >50

df_titanic[(df_titanic['sex']=='male') & (df_titanic['age']>50)]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 33          0       2  male  66.0      0      0   10.5000        S  Second
# 54          0       1  male  65.0      0      1   61.9792        C   First
# 94          0       3  male  59.0      0      0    7.2500        S   Third
# 96          0       1  male  71.0      0      0   34.6542        C   First
# 116         0       3  male  70.5      0      0    7.7500        Q   Third
# 124         0       1  male  54.0      0      1   77.2875        S   First
# 150         0       2  male  51.0      0      0   12.5250        S  Second
# 152         0       3  male  55.5      0      0    8.0500        S   Third
# 155         0       1  male  51.0      0      1   61.3792        C   First
# 170         0       1  male  61.0      0      0   33.5000        S   First
# ...

# %%
df_titanic.query('sex == "male"  and survived==1') #information when person is male and they have survived
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df_titanic.sort_values(by="age").head(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False

# %%
df_titanic.nsmallest(3,'age')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 469         1       3  female  0.75      2      1  19.2583        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False

# %%
df_titanic.nlargest(3, 'age')
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.0000        S  First  man
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True
# 96         True    A    Cherbourg    no   True

# %% [markdown]
# ## String Methods
#
# We can use the usual string methods to manipulate data inside of a dataframe. To invoke a string method use the .str attribute of a series. Since the only column that is stored as a string is the Name column we will work with that.

# %%
res=[]
for i in range(len(df_titanic)):
    res.append(df_titanic.loc[i,'sex'].upper())

df_titanic['new_gender']= res

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df_titanic["new_gender_1"] = df_titanic["sex"].str.upper()
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# The above bit of code returns the Name column as a str with all lowercase letters. Another useful string method is the contains() method, which returns a boolean if the given string contain the input string.

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Check  length
# 0      0         A/5 21171   7.2500   NaN        S  True      23
# 1      0          PC 17599  71.2833   C85        C  True      51
# 2      0  STON/O2. 3101282   7.9250   NaN        S  True      22
# ...

# %%
a="ramya,anumula"
a.split(",")
# Out:
# ['ramya', 'anumula']

# %% [markdown]
# ### Can we extract Last Name and First Name

# %%
df_titanic["Name1"] = df_titanic["Name"].str.split(",")
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Check  \
# 0      0         A/5 21171   7.2500   NaN        S  True
# 1      0          PC 17599  71.2833   C85        C  True
# 2      0  STON/O2. 3101282   7.9250   NaN        S  True
# 3      0            113803  53.1000  C123        S  True
# ...

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic[["Last","First"]]=df_titanic["Name"].str.split(",")
df_titanic.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_titanic[["Last","First"]]=df_titanic["Name"].str.split(",")
#       2 df_titanic.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4027, in DataFrame._setitem_array(self, key, value)
#    4024     return self._setitem_array(key, value)
#    4026 else:
# -> 4027     self._iset_not_inplace(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4046, in DataFrame._iset_not_inplace(self, key, value)
# ...

# %%
df_titanic[["Last","First"]]=df_titanic["Name"].str.split(",",expand=True)
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Check  \
# 0      0         A/5 21171   7.2500   NaN        S  True
# 1      0          PC 17599  71.2833   C85        C  True
# 2      0  STON/O2. 3101282   7.9250   NaN        S  True
# 3      0            113803  53.1000  C123        S  True
# ...

# %% [markdown]
# ###### Set expand  = True

# %%
#parametrs inside function
# (drop(...inplace = True ))
# reset_index(.....drop=True)
# split(....,expand=True)

# str.stringfunctions
# dt.datetimefunctions

# %% [markdown]
# ### Can we extract Gender without using "Sex" column??

# %% [markdown]
# Note that we need the escape character "\" to look for the ".".  We can easily the results of the returned series in a new column as follows.

# %% [markdown]
# We can also use these string methods on the column names. Let's say I want to replace all the underscores (there is only one) with blank spaces.  I can do that with the replace method. Recall that I access the column names through the columns attribute of any dataframe.

# %%
df_titanic["Gender"] = df_titanic["Name"].str.contains("Mr\.")
df_titanic["Gender"]
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Gender, Length: 891, dtype: bool

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Check  \
# 0      0         A/5 21171   7.2500   NaN        S  True
# 1      0          PC 17599  71.2833   C85        C  True
# 2      0  STON/O2. 3101282   7.9250   NaN        S  True
# 3      0            113803  53.1000  C123        S  True
# ...

# %%
import pandas as pd

# Create a small dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [85, 92, 78, 88],
    'Science_Score': [90, 80, 85, 95],
    'Age' : [25,30,50,49],
    'Gender':['M','F','M','M']
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#       Name  Score  Science_Score  Age Gender
# 0    Alice     85             90   25      M
# 1      Bob     92             80   30      F
# 2  Charlie     78             85   50      M
# 3    David     88             95   49      M

# %%
df
# Out:
#       Name  Score  Science_Score  Age Gender
# 0    Alice     85             90   25      M
# 1      Bob     92             80   30      F
# 2  Charlie     78             85   50      M
# 3    David     88             95   49      M

# %%
#1. for loop
for i in range(len(df)):
    df.loc[i,'new_age_1']  = df.loc[i,'Age'] * 2

# %%
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_age_1
# 0    Alice     85             90   25      M       50.0
# 1      Bob     92             80   30      F       60.0
# 2  Charlie     78             85   50      M      100.0
# 3    David     88             95   49      M       98.0

# %%
#2 apply
def my_age(x):
    return x*2

df['new_age_2'] = df['Age'].apply(my_age)
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_age_1  new_age_2
# 0    Alice     85             90   25      M       50.0         50
# 1      Bob     92             80   30      F       60.0         60
# 2  Charlie     78             85   50      M      100.0        100
# 3    David     88             95   49      M       98.0         98

# %%
#3 apply
df['new_age_3'] = df['Age'].apply(lambda x:x*2)
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_age_1  new_age_2  new_age_3
# 0    Alice     85             90   25      M       50.0         50         50
# 1      Bob     92             80   30      F       60.0         60         60
# 2  Charlie     78             85   50      M      100.0        100        100
# 3    David     88             95   49      M       98.0         98         98

# %%
#4 directy way
df['new_age_4'] = df['Age']*2
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_age_1  new_age_2  new_age_3  \
# 0    Alice     85             90   25      M       50.0         50         50
# 1      Bob     92             80   30      F       60.0         60         60
# 2  Charlie     78             85   50      M      100.0        100        100
# 3    David     88             95   49      M       98.0         98         98
#
#    new_age_4
# 0         50
# 1         60
# 2        100
# 3         98

# %%
# 5
#list(map(func,iterable))
def my_age(x):
    return x*2
df['new_age_5']= list(map(my_age,df['Age']))
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_age_1  new_age_2  new_age_3  \
# 0    Alice     85             90   25      M       50.0         50         50
# 1      Bob     92             80   30      F       60.0         60         60
# 2  Charlie     78             85   50      M      100.0        100        100
# 3    David     88             95   49      M       98.0         98         98
#
#    new_age_4  new_age_5
# 0         50         50
# 1         60         60
# 2        100        100
# 3         98         98

# %%
#way1
for i in range(len(df)):
    if df.loc[i,'Gender']=='M':
        df.loc[i,'Gender'] ='Male'
    else:
        df.loc[i,'Gender'] ='Female'

df
# Out:
#       Name  Score  Science_Score  Age  Gender  new_age_1  new_age_2  \
# 0    Alice     85             90   25    Male       50.0         50
# 1      Bob     92             80   30  Female       60.0         60
# 2  Charlie     78             85   50    Male      100.0        100
# 3    David     88             95   49    Male       98.0         98
#
#    new_age_3  new_age_4  new_age_5
# 0         50         50         50
# 1         60         60         60
# 2        100        100        100
# 3         98         98         98

# %%
#way2
def new_gender(x):
    if x=='F':
        return 'Female'
    else:
        return 'Male'

df['Gender']=df['Gender'].apply(new_gender)

# %%
df
# Out:
#       Name  Score  Science_Score  Age  Gender
# 0    Alice     85             90   25    Male
# 1      Bob     92             80   30  Female
# 2  Charlie     78             85   50    Male
# 3    David     88             95   49    Male

# %%
import pandas as pd

# Create a small dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [85, 92, 78, 88],
    'Science_Score': [90, 80, 85, 95],
    'Age' : [25,30,50,49],
    'Gender':['M','F','M','M']
}

df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Name  Score  Science_Score  Age Gender
# 0    Alice     85             90   25      M
# 1      Bob     92             80   30      F
# 2  Charlie     78             85   50      M
# 3    David     88             95   49      M

# %%
# way-3
def new_gender(x):
    if x=='F':
        return 'Female'
    else:
        return 'Male'

df['Gender']=list(map(new_gender,df['Gender']))

# %%
df
# Out:
#       Name  Score  Science_Score  Age  Gender
# 0    Alice     85             90   25    Male
# 1      Bob     92             80   30  Female
# 2  Charlie     78             85   50    Male
# 3    David     88             95   49    Male

# %%
import pandas as pd

# Create a small dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [85, 92, 78, 88],
    'Science_Score': [90, 80, 85, 95],
    'Age' : [25,30,50,49],
    'Gender':['M','F','M','M']
}

df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Name  Score  Science_Score  Age Gender
# 0    Alice     85             90   25      M
# 1      Bob     92             80   30      F
# 2  Charlie     78             85   50      M
# 3    David     88             95   49      M

# %%
# way4 -- new way of using map
# column.map({'oldvalue':'new_value','oldvalue':'new_value'})
df['Gender']= df['Gender'].map({'F':'Female','M':'Male'})

# %%
df
# Out:
#       Name  Score  Science_Score  Age  Gender
# 0    Alice     85             90   25    Male
# 1      Bob     92             80   30  Female
# 2  Charlie     78             85   50    Male
# 3    David     88             95   49    Male

# %%
d= {'scores':[[10,20,30],[40,50,60],[70,80,90]],
    'names' : ['a','b','c'] }
df= pd.DataFrame(d)
df
# Out:
#          scores names
# 0  [10, 20, 30]     a
# 1  [40, 50, 60]     b
# 2  [70, 80, 90]     c

# %%
for i in range(len(df)):
    print(df.loc[i,'scores'])
# Out:
# [10, 20, 30]
# [40, 50, 60]
# [70, 80, 90]

# %%
res=[]
for i in range(len(df)):
    s=0
    for j in df.loc[i,'scores']:
        s=s+j
    res.append(s)
print(res)
# Out:
# [60, 150, 240]

# %%
df['new_col']=res

# %%
df
# Out:
#          scores names  new_col
# 0  [10, 20, 30]     a       60
# 1  [40, 50, 60]     b      150
# 2  [70, 80, 90]     c      240

# %%
import pandas as pd

# Create a small dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [85, 92, 78, 88],
    'Science_Score': [90, 80, 85, 95],
    'Age' : [25,30,50,49],
    'Gender':['M','F','M','M']
}

df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Name  Score  Science_Score  Age Gender
# 0    Alice     85             90   25      M
# 1      Bob     92             80   30      F
# 2  Charlie     78             85   50      M
# 3    David     88             95   49      M

# %%
df[['Score','Science_Score']].apply(lambda x:x.mean(),axis=1)
# Out:
# 0    87.5
# 1    86.0
# 2    81.5
# 3    91.5
# dtype: float64

# %%
df[['Score','Science_Score']].apply(lambda x:x.mean(),axis=0)
# Out:
# Score            85.75
# Science_Score    87.50
# dtype: float64

# %%
df['Score'].apply(lambda x:x*2)
# Out:
# 0    170
# 1    184
# 2    156
# 3    176
# Name: Score, dtype: int64

# %%
df[['Score', 'Science_Score']].apply(lambda x:x.mean())
# Out:
# Score            85.75
# Science_Score    87.50
# dtype: float64

# %%
df[['Score', 'Science_Score']].apply(lambda x:x.mean(),axis=1)
# Out:
# 0    87.5
# 1    86.0
# 2    81.5
# 3    91.5
# dtype: float64

# %%
dic={"M":0,"F":1}
df['new_gender']=df['Gender'].map(dic)

# %%
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_gender
# 0    Alice     85             90   25      M           0
# 1      Bob     92             80   30      F           1
# 2  Charlie     78             85   50      M           0
# 3    David     88             95   49      M           0

# %%
df['new_1']=df.apply(lambda x:x['Age']*2,axis=1)
df['new_2']=df['Age'].apply(lambda x:x*2)

# %%
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_gender  new_gender1  \
# 0    Alice     85             90   25      M          50           50
# 1      Bob     92             80   30      F          60           60
# 2  Charlie     78             85   50      M         100          100
# 3    David     88             95   49      M          98           98
#
#    new_age  new_1  new_2
# 0       50     50     50
# 1       60     60     60
# 2      100    100    100
# 3       98     98     98

# %%
df
# Out:
#       Name  Score  Science_Score  Age Gender  new_gender  new_gender1  new_age
# 0    Alice     85             90   25      M           0           50       50
# 1      Bob     92             80   30      F           1           60       60
# 2  Charlie     78             85   50      M           0          100      100
# 3    David     88             95   49      M           0           98       98
