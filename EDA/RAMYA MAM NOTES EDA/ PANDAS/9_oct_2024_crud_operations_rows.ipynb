# %%
import numpy as np
l =np.array([1,2,3,4])
l+2
# Out:
# array([3, 4, 5, 6])

# %%
import numpy as np
l1 =np.array([1,2,3,4])
l2 =np.array([10,12,13,14])
l1+l2
# Out:
# array([11, 14, 16, 18])

# %%
dict1={'s1':[1,2,3,4,5],
         'sname':['k1','k2','k3','k4','k5'],
         'Gender':['f','f','m','m','m'],
        'Marks':[10,99,100,95,90],
         'Group':['cse','cse','mech','it','it']}

import pandas as pd
df = pd.DataFrame(dict1)

# %%
df
# Out:
#    s1 sname Gender  Marks Group
# 0   1    k1      f     10   cse
# 1   2    k2      f     99   cse
# 2   3    k3      m    100  mech
# 3   4    k4      m     95    it
# 4   5    k5      m     90    it

# %%
# creating a col- way1
df['new_marks']= df['Marks'] + 30

# %%
df
# Out:
#    s1 sname Gender  Marks Group  new_marks
# 0   1    k1      f     10   cse         40
# 1   2    k2      f     99   cse        129
# 2   3    k3      m    100  mech        130
# 3   4    k4      m     95    it        125
# 4   5    k5      m     90    it        120

# %%
# way -2 creatting a column 
df['temp']= df['Marks']+df['new_marks']

# %%
df
# Out:
#    s1 sname Gender  Marks Group  new_marks  temp
# 0   1    k1      f     10   cse         40    50
# 1   2    k2      f     99   cse        129   228
# 2   3    k3      m    100  mech        130   230
# 3   4    k4      m     95    it        125   220
# 4   5    k5      m     90    it        120   210

# %%
# way -3 giving same values in the column
df['placed'] = False

# %%
df
# Out:
#    s1 sname Gender  Marks Group  new_marks  temp  placed
# 0   1    k1      f     10   cse         40    50   False
# 1   2    k2      f     99   cse        129   228   False
# 2   3    k3      m    100  mech        130   230   False
# 3   4    k4      m     95    it        125   220   False
# 4   5    k5      m     90    it        120   210   False

# %%
l = [20,22,23,24,np.nan]
df['age']= l

# %%
df
# Out:
#    s1 sname Gender  Marks Group  new_marks  temp  placed   age
# 0   1    k1      f     10   cse         40    50   False  20.0
# 1   2    k2      f     99   cse        129   228   False  22.0
# 2   3    k3      m    100  mech        130   230   False  23.0
# 3   4    k4      m     95    it        125   220   False  24.0
# 4   5    k5      m     90    it        120   210   False   NaN

# %%
res=[]
for i in df['Gender']:
    res.append(i.upper())
res
# Out:
# ['F', 'F', 'M', 'M', 'M']

# %%
df['new_gender'] = res

# %%
df
# Out:
#    s1 sname Gender  Marks Group  new_marks  temp  placed   age new_gender
# 0   1    k1      f     10   cse         40    50   False  20.0          F
# 1   2    k2      f     99   cse        129   228   False  22.0          F
# 2   3    k3      m    100  mech        130   230   False  23.0          M
# 3   4    k4      m     95    it        125   220   False  24.0          M
# 4   5    k5      m     90    it        120   210   False   NaN          M

# %%
df['new_Group']=[i.upper() for i in df['Group']]

# %%
df
# Out:
#    s1 sname Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1      f     10   cse         40    50   False  20.0          F
# 1   2    k2      f     99   cse        129   228   False  22.0          F
# 2   3    k3      m    100  mech        130   230   False  23.0          M
# 3   4    k4      m     95    it        125   220   False  24.0          M
# 4   5    k5      m     90    it        120   210   False   NaN          M
#
#   new_Group
# 0       CSE
# 1       CSE
# 2      MECH
# 3        IT
# 4        IT

# %%
res=[i.upper() for i in df['Gender']]
res
# Out:
# ['F', 'F', 'M', 'M', 'M']

# %%
df['Gender'] =res

# %%
df
# Out:
#    s1 sname Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1      F     10   cse         40    50   False  20.0          F
# 1   2    k2      F     99   cse        129   228   False  22.0          F
# 2   3    k3      M    100  mech        130   230   False  23.0          M
# 3   4    k4      M     95    it        125   220   False  24.0          M
# 4   5    k5      M     90    it        120   210   False   NaN          M
#
#   new_Group
# 0       CSE
# 1       CSE
# 2      MECH
# 3        IT
# 4        IT

# %%
res=[]
for i in df['Gender']:
    if i=='F':
        res.append('Female')
    else:
        res.append('Male')

res
# Out:
# ['Female', 'Female', 'Male', 'Male', 'Male']

# %%
df['Gender'] =res

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1  Female     10   cse         40    50   False  20.0          F
# 1   2    k2  Female     99   cse        129   228   False  22.0          F
# 2   3    k3    Male    100  mech        130   230   False  23.0          M
# 3   4    k4    Male     95    it        125   220   False  24.0          M
# 4   5    k5    Male     90    it        120   210   False   NaN          M
#
#   new_Group
# 0       CSE
# 1       CSE
# 2      MECH
# 3        IT
# 4        IT

# %%
# res=[]
#appraoch 1
for i in df['Gender']:
    if i=='F':
        res.append('Female')
    else:
        res.append('Male')

res

# %%
# approach2 -- map function
def new_gender(val):
    if val=='F':
        return 'Female'
    else:
        return 'Male'

# %%
list(map(new_gender,['F','M','M']))
# Out:
# ['Female', 'Male', 'Male']

# %%
new_gender(['F','M','M'])
# Out:
# 'Male'

# %%
new_gender('M')
# Out:
# 'Male'

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1  Female     10   cse         40    50   False  20.0          F
# 1   2    k2  Female     99   cse        129   228   False  22.0          F
# 2   3    k3    Male    100  mech        130   230   False  23.0          M
# 3   4    k4    Male     95    it        125   220   False  24.0          M
# 4   5    k5    Male     90    it        120   210   False   NaN          M
#
#   new_Group
# 0       CSE
# 1       CSE
# 2      MECH
# 3        IT
# 4        IT

# %%
def temp(val):
    if val=='F':
        return 'Female'
    else:
        return 'Male'

# %%
x = list(map(temp,df['new_gender']))
df['new_gender']= x

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1  Female     10   cse         40    50   False  20.0       Male
# 1   2    k2  Female     99   cse        129   228   False  22.0       Male
# 2   3    k3    Male    100  mech        130   230   False  23.0       Male
# 3   4    k4    Male     95    it        125   220   False  24.0       Male
# 4   5    k5    Male     90    it        120   210   False   NaN       Male
#
#   new_Group
# 0       CSE
# 1       CSE
# 2      MECH
# 3        IT
# 4        IT

# %%
# way3
def temp(val):
    if val=='Female':
        return 1
    else:
        return 0

# %%
df['Gender'] = df['Gender'].apply(temp)

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1       1     10   cse         40    50   False  20.0       Male
# 1   2    k2       1     99   cse        129   228   False  22.0       Male
# 2   3    k3       0    100  mech        130   230   False  23.0       Male
# 3   4    k4       0     95    it        125   220   False  24.0       Male
# 4   5    k5       0     90    it        120   210   False   NaN       Male
#
#   new_Group
# 0       CSE
# 1       CSE
# 2      MECH
# 3        IT
# 4        IT

# %%
# way-4
df['new_val'] = df['Gender'].apply(lambda x:'Female' if x==1 else 'Male')

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1       1     10   cse         40    50   False  20.0       Male
# 1   2    k2       1     99   cse        129   228   False  22.0       Male
# 2   3    k3       0    100  mech        130   230   False  23.0       Male
# 3   4    k4       0     95    it        125   220   False  24.0       Male
# 4   5    k5       0     90    it        120   210   False   NaN       Male
#
#   new_Group new_val
# 0       CSE  Female
# 1       CSE  Female
# 2      MECH    Male
# 3        IT    Male
# 4        IT    Male

# %%
# way-5
df['Gender'] = df['Gender'].apply(lambda x:'Female' if x==1 else 'Male')

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1  Female     10   cse         40    50   False  20.0       Male
# 1   2    k2  Female     99   cse        129   228   False  22.0       Male
# 2   3    k3    Male    100  mech        130   230   False  23.0       Male
# 3   4    k4    Male     95    it        125   220   False  24.0       Male
# 4   5    k5    Male     90    it        120   210   False   NaN       Male
#
#   new_Group new_val
# 0       CSE  Female
# 1       CSE  Female
# 2      MECH    Male
# 3        IT    Male
# 4        IT    Male

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1  Female     10   cse         40    50   False  20.0       Male
# 1   2    k2  Female     99   cse        129   228   False  22.0       Male
# 2   3    k3    Male    100  mech        130   230   False  23.0       Male
# 3   4    k4    Male     95    it        125   220   False  24.0       Male
# 4   5    k5    Male     90    it        120   210   False   NaN       Male
#
#   new_Group new_val
# 0       CSE  Female
# 1       CSE  Female
# 2      MECH    Male
# 3        IT    Male
# 4        IT    Male

# %%
df.drop(['new_val'],axis=1,inplace = True)

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks  temp  placed   age new_gender  \
# 0   1    k1  Female     10   cse         40    50   False  20.0       Male
# 1   2    k2  Female     99   cse        129   228   False  22.0       Male
# 2   3    k3    Male    100  mech        130   230   False  23.0       Male
# 3   4    k4    Male     95    it        125   220   False  24.0       Male
# 4   5    k5    Male     90    it        120   210   False   NaN       Male
#
#   new_Group
# 0       CSE
# 1       CSE
# 2      MECH
# 3        IT
# 4        IT

# %%
df.drop(['placed','temp','new_gender'],axis=1,inplace = True)

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks   age new_Group
# 0   1    k1  Female     10   cse         40  20.0       CSE
# 1   2    k2  Female     99   cse        129  22.0       CSE
# 2   3    k3    Male    100  mech        130  23.0      MECH
# 3   4    k4    Male     95    it        125  24.0        IT
# 4   5    k5    Male     90    it        120   NaN        IT

# %%
# add multiple columns
df[['temp1','temp2','temp3']]=0

# %%
df
# Out:
#    s1 sname  Gender  Marks Group  new_marks   age new_Group  temp1  temp2  \
# 0   1    k1  Female     10   cse         40  20.0       CSE      0      0
# 1   2    k2  Female     99   cse        129  22.0       CSE      0      0
# 2   3    k3    Male    100  mech        130  23.0      MECH      0      0
# 3   4    k4    Male     95    it        125  24.0        IT      0      0
# 4   5    k5    Male     90    it        120   NaN        IT      0      0
#
#    temp3
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# # deleteing the column

# %% [markdown]
# pandas drop()
#
# # axis =1 --- row wise operations --- entire column we are deleting
# # axis=0 ---  column wise operation --- entire row we are deleting

# %% [markdown]
# other functions
# # axis --- 0 --- columns wise operation
# # axis ---- 1--- row wise operations

# %%
df
# Out:
#    s1 sname Gender  Marks Group  x
# 0   1    k1      f     10   cse  0
# 1   2    k2      f     99   cse  0
# 2   3    k3      m    100  mech  0
# 3   4    k4      m     95    it  0
# 4   5    k5      m     90    it  0

# %%
df
# Out:
#     s1 sname Gender  Marks Group  x
# 0    1    k1      f     10   cse  0
# 1    2    k2      f     99   cse  0
# 2    3    k3      m    100  mech  0
# 3    4    k4      m     95    it  0
# 4  100    k5      m     90    it  0

# %%
df.loc[4]
# Out:
# s1         5
# sname     k5
# Gender     m
# Marks     90
# Group     it
# x          0
# Name: 4, dtype: object

# %%
# adding a row
df.loc[5] = {'s1':5, 'sname':'k6','Gender':'m','Marks':100,'Group':'it','x':0}
# modifying a row
df.loc[4] = {'s1':100, 'sname':'k5','Gender':'m','Marks':90,'Group':'it','x':0}

# %%
df
# Out:
#     s1 sname Gender  Marks Group  x
# 0    1    k1      f     10   cse  0
# 1    2    k2      f     99   cse  0
# 2    3    k3      m    100  mech  0
# 3    4    k4      m     95    it  0
# 4  100    k5      m     90    it  0
# 5    5    k6      m    100    it  0

# %%
temp= df.copy()
temp
# Out:
#     s1 sname Gender  Marks Group  x
# 0    1    k1      f     10   cse  0
# 1    2    k2      f     99   cse  0
# 2    3    k3      m    100  mech  0
# 3    4    k4      m     95    it  0
# 4  100    k5      m     90    it  0
# 5    5    k6      m    100    it  0

# %%
# sorting based on columns
df.sort_values(by='Marks',ascending= False,inplace= True)
# sorting based on row indexes
df.sort_index(inplace= True)

# %%
df
# Out:
#     s1 sname Gender  Marks Group  x
# 2    3    k3      m    100  mech  0
# 5    5    k6      m    100    it  0
# 1    2    k2      f     99   cse  0
# 3    4    k4      m     95    it  0
# 4  100    k5      m     90    it  0
# 0    1    k1      f     10   cse  0

# %%
df
# Out:
#     s1 sname Gender  Marks Group  x
# 2    3    k3      m    100  mech  0
# 5    5    k6      m    100    it  0
# 1    2    k2      f     99   cse  0
# 3    4    k4      m     95    it  0
# 4  100    k5      m     90    it  0
# 0    1    k1      f     10   cse  0

# %%
df
# Out:
#     s1 sname Gender  Marks Group  x
# 0    1    k1      f     10   cse  0
# 1    2    k2      f     99   cse  0
# 2    3    k3      m    100  mech  0
# 3    4    k4      m     95    it  0
# 4  100    k5      m     90    it  0
# 5    5    k6      m    100    it  0

# %%
df.iloc[4] = [1000, 'k1000','m','95','it',0]

# %%
df
# Out:
#      s1  sname Gender Marks Group  x
# 0     1     k1      f    10   cse  0
# 1     2     k2      f    99   cse  0
# 2     3     k3      m   100  mech  0
# 3     4     k4      m    95    it  0
# 4  1000  k1000      m    95    it  0
# 5     5     k6      m   100    it  0

# %%
temp
# Out:
#     s1 sname Gender  Marks Group  x
# 0    1    k1      f     10   cse  0
# 1    2    k2      f     99   cse  0
# 2    3    k3      m    100  mech  0
# 3    4    k4      m     95    it  0
# 4  100    k5      m     90    it  0
# 5    5    k6      m    100    it  0

# %%
temp.loc[3.5] = [1000, 'k1000','m','95','it',0]

# %%
temp
# Out:
#        s1  sname Gender Marks Group  x
# 0.0     1     k1      f    10   cse  0
# 1.0     2     k2      f    99   cse  0
# 2.0     3     k3      m   100  mech  0
# 3.0     4     k4      m    95    it  0
# 4.0   100     k5      m    90    it  0
# 5.0     5     k6      m   100    it  0
# 3.5  1000  k1000      m    95    it  0

# %%
temp.sort_index(inplace=True)

# %%
temp
# Out:
#        s1  sname Gender Marks Group  x
# 0.0     1     k1      f    10   cse  0
# 1.0     2     k2      f    99   cse  0
# 2.0     3     k3      m   100  mech  0
# 3.0     4     k4      m    95    it  0
# 3.5  1000  k1000      m    95    it  0
# 4.0   100     k5      m    90    it  0
# 5.0     5     k6      m   100    it  0

# %%
temp.reset_index(drop= True,inplace=True) 
# reset all indexes to 0,1,2,3....
#.and to drop the older index use parm --- drop =True

# %%
temp
# Out:
#      s1  sname Gender Marks Group  x
# 0     1     k1      f    10   cse  0
# 1     2     k2      f    99   cse  0
# 2     3     k3      m   100  mech  0
# 3     4     k4      m    95    it  0
# 4  1000  k1000      m    95    it  0
# 5   100     k5      m    90    it  0
# 6     5     k6      m   100    it  0

# %%
df
# Out:
#        s1  sname Gender Marks Group  x
# 0.0     1     k1      f    10   cse  0
# 1.0     2     k2      f    99   cse  0
# 2.0     3     k3      m   100  mech  0
# 2.5  2000   k200      m   200   cse  0
# 3.0     4     k4      m    95    it  0
# 3.5  1000  k1000      m    95    it  0
# 4.0  1000  k1000      m    95    it  0
# 5.0     5     k6      m   100    it  0

# %%
# between 2nd and 3rd row when u want to add
# adding a row in between 3rd and 4th row
df.loc[2.5] = [2000,'k200','m',200,'cse',0]

# %%
df.sort_index(inplace= True)
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      s1  sname Gender Marks Group  x
# 0     1     k1      f    10   cse  0
# 1     2     k2      f    99   cse  0
# 2     3     k3      m   100  mech  0
# 3  2000   k200      m   200   cse  0
# 4  2000   k200      m   200   cse  0
# 5     4     k4      m    95    it  0
# 6  1000  k1000      m    95    it  0
# 7  1000  k1000      m    95    it  0
# 8     5     k6      m   100    it  0

# %%
# dropping a row
df.drop(index=7,axis=0,inplace=True)

# %%
df
# Out:
#      s1  sname Gender Marks Group  x
# 0     1     k1      f    10   cse  0
# 1     2     k2      f    99   cse  0
# 2     3     k3      m   100  mech  0
# 3  2000   k200      m   200   cse  0
# 4  2000   k200      m   200   cse  0
# 5     4     k4      m    95    it  0
# 6  1000  k1000      m    95    it  0
# 8     5     k6      m   100    it  0

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#      s1  sname Gender Marks Group  x
# 0     1     k1      f    10   cse  0
# 1     2     k2      f    99   cse  0
# 2     3     k3      m   100  mech  0
# 3  2000   k200      m   200   cse  0
# 4  2000   k200      m   200   cse  0
# 5     4     k4      m    95    it  0
# 6  1000  k1000      m    95    it  0
# 7     5     k6      m   100    it  0

# %%
# task:  add a column in between

# %%
# drop 
#axis= 0 -- rows
#axis=1 -- columns

# %% [markdown]
# # task questions

# %%
# dataframe creation
# 
import numpy as np
import pandas as pd
data={ "PatientID":[1,2,3,4,5],
        "Pname": ["x1","x2","x3",np.nan,"x5"],
        "Gender":["M","F","M","M","M"],
        "Age": [40,45,49,50,60],
        "BpLevels":[92,100,112,120,85]}
df=pd.DataFrame(data)
df
# Out:
#    PatientID Pname Gender  Age  BpLevels
# 0          1    x1      M   40        92
# 1          2    x2      F   45       100
# 2          3    x3      M   49       112
# 3          4   NaN      M   50       120
# 4          5    x5      M   60        85

# %%
# lowest bp
df.loc[:,'BpLevels'].min()
# Out:
# 85

# %%
# patient name with low bp 
df.loc[df['BpLevels']==df['BpLevels'].min(),'Pname']

# %%
# how many male and how many female
df['Gender'].value_counts()
# Out:
# Gender
# M    4
# F    1
# Name: count, dtype: int64

# %%
# how many patient names do i know?
# how many non null values are there?
df['Pname'].count()
# Out:
# 4

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels
# 0          1    x1      M   40        92
# 1          2    x2      F   45       100
# 2          3    x3      M   49       112
# 3          4   NaN      M   50       120
# 4          5    x5      M   60        85

# %%
# filter those patients whose age is not greater than 50
# and whose Bp is not greater than 100
# way1
df[(df['Age'] <=50) & (df['BpLevels'] <=100)]
# Out:
#    PatientID Pname Gender  Age  BpLevels
# 0          1    x1      M   40        92
# 1          2    x2      F   45       100

# %%
# way-2 
# use this instead of above syntax
df[~(df['Age'] >50) & ~(df['BpLevels'] >100)]
# Out:
#    PatientID Pname Gender  Age  BpLevels
# 0          1    x1      M   40        92
# 1          2    x2      F   45       100

# %%
# add a new column called diabetes
df['Dibetes'] = False

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Dibetes
# 0          1    x1      M   40        92    False
# 1          2    x2      F   45       100    False
# 2          3    x3      M   49       112    False
# 3          4   NaN      M   50       120    False
# 4          5    x5      M   60        85    False

# %%
df= df.rename(columns={'Dibetes':'Diabetes'})

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100     False
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85     False

# %%
df['Diabetes'] =False

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100     False
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85     False

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100     False
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85     False

# %%
df1= df.copy()
df1
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100     False
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85     False

# %%
#6
# way1
df.loc[(df['Gender']=='M') & (df['Age']>50),'Diabetes'] = True
df.loc[(df['Gender']=='F'),'Diabetes'] = True

# shortcut : check it : way 2-- using apply can we do this?

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100      True
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85      True

# %%
temp('Gender')

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100      True
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85      True

# %%
df['Childrens Age']= df['Age'].apply(lambda x:x/2)

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes  Childrens Age
# 0          1    x1      M   40        92     False           20.0
# 1          2    x2      F   45       100      True           22.5
# 2          3    x3      M   49       112     False           24.5
# 3          4   NaN      M   50       120     False           25.0
# 4          5    x5      M   60        85      True           30.0

# %% [markdown]
# temp('Male',)

# %%
df['Diabetes'].apply(temp(df['Gender'],df['Age']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4744\584850262.py in ?()
# ----> 1 df['Diabetes'].apply(temp(df['Gender'],df['Age']))
#
# ~\AppData\Local\Temp\ipykernel_4744\662275050.py in ?(x, y)
#       1 def temp(x,y):
# ----> 2     if x=='Male':
#       3         if y>50:
#       4             return True
#       5         else:
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
def temp(x,y):
    if x=='Male':
        if y>50:
            return True
        else:
            return False
    else:
        return True

# %%
temp('Female',30)
# Out:
# True

# %%
temp(['M','F','M'],[20,30,40])
# Out:
# True

# %%
df.apply(temp(df['Gender'],df['Age']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4744\1429290354.py in ?()
# ----> 1 df.apply(temp(df['Gender'],df['Age']))
#
# ~\AppData\Local\Temp\ipykernel_4744\662275050.py in ?(x, y)
#       1 def temp(x,y):
# ----> 2     if x=='Male':
#       3         if y>50:
#       4             return True
#       5         else:
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df1
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100     False
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85     False

# %%
def temp1(x):
    if x=='F':
        return True
    else:
        return False

# %%
df1
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100     False
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85     False

# %%
df['new_gender'] = df1['Gender'].apply(temp1)
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes  Childrens Age  new_gender
# 0          1    x1      M   40        92     False           20.0       False
# 1          2    x2      F   45       100      True           22.5        True
# 2          3    x3      M   49       112     False           24.5       False
# 3          4   NaN      M   50       120     False           25.0       False
# 4          5    x5      M   60        85      True           30.0       False

# %%
df1
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes
# 0          1    x1      M   40        92     False
# 1          2    x2      F   45       100     False
# 2          3    x3      M   49       112     False
# 3          4   NaN      M   50       120     False
# 4          5    x5      M   60        85     False

# %%
def temp1(x):
    if x=='F':
        return True
    else:
        return False

# %%
df1['Diabetes'] = df1['Gender'].apply(lambda x:True if x=='F' else False)
df1['Diabetes1']=  df1['Gender'].apply(temp1)
df1['Diabetes2']= list(map(temp1,df1['Gender']))

# %%
df1
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes  Diebetes_new  Diabetes1  \
# 0          1    x1      M   40        92     False         False      False
# 1          2    x2      F   45       100      True          True       True
# 2          3    x3      M   49       112     False         False      False
# 3          4   NaN      M   50       120     False         False      False
# 4          5    x5      M   60        85     False         False      False
#
#    Diabetes2
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False

# %%
df.drop('new_gender',axis=1) # dropping a column
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes  Childrens Age
# 0          1    x1      M   40        92     False           20.0
# 1          2    x2      F   45       100      True           22.5
# 2          3    x3      M   49       112     False           24.5
# 3          4   NaN      M   50       120     False           25.0
# 4          5    x5      M   60        85     False           30.0

# %%
df
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes  Childrens Age  new_gender
# 0          1    x1      M   40        92     False           20.0       False
# 1          2    x2      F   45       100      True           22.5        True
# 2          3    x3      M   49       112     False           24.5       False
# 3          4   NaN      M   50       120     False           25.0       False
# 4          5    x5      M   60        85     False           30.0       False

# %%
df1
# Out:
#    PatientID Pname Gender  Age  BpLevels  Diabetes  Diebetes_new  Diabetes1  \
# 0          1    x1      M   40        92     False         False      False
# 1          2    x2      F   45       100      True          True       True
# 2          3    x3      M   49       112     False         False      False
# 3          4   NaN      M   50       120     False         False      False
# 4          5    x5      M   60        85     False         False      False
#
#    Diabetes2
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
