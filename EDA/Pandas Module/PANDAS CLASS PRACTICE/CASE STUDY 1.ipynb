# %%
import numpy as np
import pandas as pd

# %%
y

# %%
# Understand the data
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
# Cleaning the data
# if there are more no of null values drop the column

# %%
# Drop the remark column for permanent we use "inplace" = True"

# %%
df.drop(columns="Remarks",inplace = True)

# %%
# After dropping the column
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD'],
#       dtype='object')

# %%
# Renaming the Columns
df.rename(columns = {"Sr No" : "s_no","Date dd/mm/yyyy" : "date",
                     'Startup Name': "startup",'Industry Vertical' : "vertical",
                    "SubVertical": "subvertical","City": "city","Location":"location",
                    "Investors Name" : "investors","InvestornType" : "investor type",
                    "Amount in USD": "amount"}, inplace = True)

# %%
df
# Out:
#       s_no        date                       startup             vertical  \
# 0        1  09/01/2020                        BYJU’S               E-Tech
# 1        2  13/01/2020                        Shuttl       Transportation
# 2        3  09/01/2020                     Mamaearth           E-commerce
# 3        4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4        5  02/01/2020                        Fashor  Fashion and Apparel
# ...    ...         ...                           ...                  ...
# 3039  3040  29/01/2015                    Printvenue                  NaN
# 3040  3041  29/01/2015                      Graphene                  NaN
# 3041  3042  30/01/2015                Mad Street Den                  NaN
# 3042  3043  30/01/2015                     Simplotel                  NaN
# 3043  3044  31/01/2015              couponmachine.in                  NaN
#
#                                 subvertical City  Location  \
# ...

# %%
df["amount"] = df["amount"].fillna("0")

# %%
# remove commas
df["amount"].str.replace(",","")
# Out:
# 0       200000000
# 1         8048394
# 2        18358860
# 3         3000000
# 4         1800000
#           ...
# 3039      4500000
# 3040       825000
# 3041      1500000
# 3042            0
# 3043       140000
# Name: amount, Length: 3044, dtype: object

# %%
df["amount"]= df["amount"].replace("undisclosed","0").replace("Undisclosed","0")

# %%
df["amount"] =  df["amount"].replace("unknown","0")

# %%
df
# Out:
#       s_no        date                       startup             vertical  \
# 0        1  09/01/2020                        BYJU’S               E-Tech
# 1        2  13/01/2020                        Shuttl       Transportation
# 2        3  09/01/2020                     Mamaearth           E-commerce
# 3        4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4        5  02/01/2020                        Fashor  Fashion and Apparel
# ...    ...         ...                           ...                  ...
# 3039  3040  29/01/2015                    Printvenue                  NaN
# 3040  3041  29/01/2015                      Graphene                  NaN
# 3041  3042  30/01/2015                Mad Street Den                  NaN
# 3042  3043  30/01/2015                     Simplotel                  NaN
# 3043  3044  31/01/2015              couponmachine.in                  NaN
#
#                                 subvertical City  Location  \
# ...

# %% [markdown]
# 1. when we replace issing values with 0 or any value we are changing the distribution.
# 2. fillna(0) fillls all the missing values with 0
# 3.
