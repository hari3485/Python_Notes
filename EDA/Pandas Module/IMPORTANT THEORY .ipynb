# %% [markdown]
# 1. when we replace issing values with 0 or any value we are changing the distribution.
# 2. fillna(0) fillls all the missing values with 0
# 3. plotly library histogram
# 4. when we drop outliers we may loose valuable information
# 5. if we want to see dataframe where we can uderstand better clarity use "melt"
# 6. use pivot table for better report making.
# 7. fill null values with "-" to look report simple.
# 8. Summarisation report generation can be used by groupby,pivot table,crosstab.
# 9. we can select particular dtypes for particular calculations use "select_dtypes"
# 10. Heat map use "annot" = True for getting correlation values in heatmap
# 11. to calculat freq in stcaked barplot
# 12. for comparin 2 numerical columns use "SCATTER PLOT"
#
#
#
# ![boxplot.jpg](attachment:boxplot.jpg)
