# %%
import seaborn 
print(seaborn.__version__)
# Out:
# 0.13.2

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Downloading data set from seaborn
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris[iris.duplicated( keep = False)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 101           5.8          2.7           5.1          1.9  virginica
# 142           5.8          2.7           5.1          1.9  virginica

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(data = iris , x = "sepal_length", y = "sepal_width" , hue = "species" , marker = "h")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.color_palette("pastel")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.color_palette("dark")
# Out:
# [(0.0, 0.10980392156862745, 0.4980392156862745),
#  (0.6941176470588235, 0.25098039215686274, 0.050980392156862744),
#  (0.07058823529411765, 0.44313725490196076, 0.10980392156862745),
#  (0.5490196078431373, 0.03137254901960784, 0.0),
#  (0.34901960784313724, 0.11764705882352941, 0.44313725490196076),
#  (0.34901960784313724, 0.1843137254901961, 0.050980392156862744),
#  (0.6352941176470588, 0.20784313725490197, 0.5098039215686274),
#  (0.23529411764705882, 0.23529411764705882, 0.23529411764705882),
#  (0.7215686274509804, 0.5215686274509804, 0.0392156862745098),
#  (0.0, 0.38823529411764707, 0.4549019607843137)]

# %%
sns.color_palette("bright")
# Out:
# [(0.00784313725490196, 0.24313725490196078, 1.0),
#  (1.0, 0.48627450980392156, 0.0),
#  (0.10196078431372549, 0.788235294117647, 0.2196078431372549),
#  (0.9098039215686274, 0.0, 0.043137254901960784),
#  (0.5450980392156862, 0.16862745098039217, 0.8862745098039215),
#  (0.6235294117647059, 0.2823529411764706, 0.0),
#  (0.9450980392156862, 0.2980392156862745, 0.7568627450980392),
#  (0.6392156862745098, 0.6392156862745098, 0.6392156862745098),
#  (1.0, 0.7686274509803922, 0.0),
#  (0.0, 0.8431372549019608, 1.0)]

# %%
sns.color_palette("deep")
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
sns.color_palette("muted")
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882),
#  (0.8627450980392157, 0.49411764705882355, 0.7529411764705882),
#  (0.4745098039215686, 0.4745098039215686, 0.4745098039215686),
#  (0.8352941176470589, 0.7333333333333333, 0.403921568627451),
#  (0.5098039215686274, 0.7764705882352941, 0.8862745098039215)]

# %%
sns.color_palette("colorblind")
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844),
#  (0.792156862745098, 0.5686274509803921, 0.3803921568627451),
#  (0.984313725490196, 0.6862745098039216, 0.8941176470588236),
#  (0.5803921568627451, 0.5803921568627451, 0.5803921568627451),
#  (0.9254901960784314, 0.8823529411764706, 0.2),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Sample data
data = np.random.rand(10, 10)

# Plot with cmap="Pastel1"
plt.figure(figsize=(6, 6))
sns.heatmap(data, cmap="Pastel1", annot=True)
plt.title("Pastel1 Color Map")
plt.show()

# %%
# Plot with cmap="bright"
plt.figure(figsize=(6, 6))
sns.heatmap(data, cmap = "rainbow", annot=True)
plt.title("Bright Color Map")
plt.show()

# %%
# Plot with cmap="bright"
plt.figure(figsize=(6, 6))
sns.heatmap(data, cmap = "magma", annot=True)
plt.title("Bright Color Map")
plt.show()

# %%
# Plot with cmap="bright"
plt.figure(figsize=(6, 6))
sns.heatmap(data, cmap = "turbo", annot=True)
plt.title("Bright Color Map")
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(data = iris , x = "sepal_length", y = "sepal_width" , hue = "species" , 
                marker = "^" , color = "dark" , s = 50)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = iris , x = "petal_length" , y = "petal_width", hue = "species" , marker = "*")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# SCatter plot is for numerical vs numerical

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(data = df,x = "bill_length_mm", y = "bill_depth_mm" 
            , hue = "island", marker = "^" , palette = "dark", s = 50)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(data = df,x = "bill_length_mm", y = "bill_depth_mm" 
            , hue = "island", marker = "^" , palette = "dark", s = 50 , style = "species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
import matplotlib.pyplot as plt 
g =sns.FacetGrid(df,hue = "species", col = "island")
g.map(sns.scatterplot,"bill_length_mm","bill_depth_mm")
g.add_legend()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(data = df,x = "flipper_length_mm",
                 y = "body_mass_g")
sns.regplot(data = df, x = "flipper_length_mm", 
                y = "body_mass_g",
               line_kws = {"color" :"m"})
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data = df,x = "bill_length_mm",
                 y = "flipper_length_mm")
sns.regplot(data = df, x = "bill_length_mm", 
                y = "flipper_length_mm",
               line_kws = {"color" :"k"})
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data = df,x = "bill_length_mm",
                 y = "bill_depth_mm")
sns.regplot(data = df, x = "bill_length_mm", 
                y = "bill_depth_mm",
               line_kws = {"color" :"g"})
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
df = pd.read_csv("train (1).csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# in Order to draw a median line to the scatter plot

sns.scatterplot(df , x = "Age" , y = "Fare" , hue = "Pclass" , palette = "dark")
plt.axhline(y = df["Fare"].quantile(0.7), color = "red", linestyle = "--",linewidth = 2)

# %%
plt.axhline(y = df["Fare"].quantile(0.7), color = "red", linestyle = "--",linewidth = 2)

# %%
df[["Age","Fare"]].corr()*100
# Out:
#              Age        Fare
# Age   100.000000    9.606669
# Fare    9.606669  100.000000

# %%
## COUNT PLOT 
## For counting the categories in the particular column

# %%
plt.figure(figsize = (5,4))
sns.countplot(df , x = "species" , color = "g")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 plt.figure(figsize = (5,4))
# ----> 2 sns.countplot(df , x = "species" , color = "g")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
# To convert the box plot into horizontal use y variable
plt.figure(figsize = (5,4))
sns.countplot(df , y = "species" , color = "g", width = 0.4)

# %%
plt.figure(figsize = (5,4))
sns.countplot(df , y = "island" , hue = "species" ,  width = 0.4 , palette = "dark")
plt.title(" count of penguin species")

# %%
 # Inorder to get Vertical columns put "X"
plt.figure(figsize = (5,4))
sns.countplot(df , x = "island" , hue = "species" ,  width = 0.4 , palette = "dark")
plt.title(" count of penguin species")

# %%
# IMPORTANT EXAMPLE TO KNOW THE COUNTS
import plotly.express as px
import pandas as pd

# Create count plot
fig = px.histogram(df, x='species', color='species',
                   category_orders={"species": df['species'].value_counts().index},
                   title='Count Plot using Plotly')

# Show plot
fig.show()

# %%
tips = sns.load_dataset("tips")
tips

# %%
tips.head()

# %%
tips.isna().sum()

# %%
pd.crosstab(tips["day"] , tips["time"] , margins = True)

# %%
pd.crosstab(tips["day"] , tips["time"] , margins = True).T

# %%
fig = px.histogram(tips, x='smoker', color='smoker',
                   category_orders={"smoker": tips['smoker'].value_counts().index},
                   title='Count Plot using Plotly')
fig

# %%
plt.figure(figsize = (5,3))
sns.countplot(data = tips , y = "day" , width = 0.3 , hue = "smoker")

# %% [markdown]
# # PIE PLOT

# %%
# Pie Plot 
day_count = tips["day"].value_counts()
day_count

# %%
plt.figure(figsize = (5,3))
plt.pie(day_count ,
       labels = day_count.index,
       autopct = "%1.2f%%",
        colors = plt.style.use("ggplot"),
        shadow = True,
        explode = [0.1,0,0,0]);

# %%
smoker_count = tips["smoker"].value_counts()
smoker_count

# %%
plt.figure(figsize = (5,3))
plt.pie(smoker_count ,
       labels = smoker_count.index,
       autopct = "%1.2f%%",
        colors = plt.style.use("ggplot"),
        shadow = True,
        explode = [0.1,0]);

# %%
# Which island contains most number
island_count = df["island"].value_counts()
island_count

# %%
plt.figure(figsize = (5,3))
plt.pie(island_count,
       labels = island_count.index,
       autopct = "%1.2f%%",
        colors = plt.style.use("ggplot"),
        shadow = True,
        explode = [0.1,0,0.2]);

# %%
plt.figure(figsize = (10,4))
sns.histplot(df , x = "body_mass_g",
             bins = 10 , kde = True , color = "magenta")
plt.axvline(x = 2700 , color "g" , linestyle = "--")
plt.axvline(x = 3060 , color "k", linestyle = "--")
plt.axvline(x = 3420 ,  color "b", linestyle = "--")
plt.xvline(x = 3780 ,  color "r",linestyle = "--")

# %% [markdown]
# # CASE STUDY

# %%
df = pd.read_csv("auto-mpg.csv")
df

# %%
df.head()

# %%
df.describe().T

# %%
df.info()

# %%
# When we have to find distribution use "KDE PLOT" or "HISTOGRAM"
# "KDE" gives better understanding
df["mpg"].plot(kind = "hist")

# %%
sns.histplot(data = df , x = df["mpg"] , kde = True , color = "g")

# %%
# How many cars are from each origin (USA,Europe,Japan)
df["origin"].value_counts()

# %%
df["origin"] = df["origin"].map({1:"USA",2:"Europe",3:"Japan"})

# %%
df["origin"].value_counts()

# %%
sns.countplot(data = df, x = df["origin"] ,color = "k" )

# %%
# Percentage of cylinders

# %%
sns.boxplot(data = df, x = df["cylinders"] , y = df["mpg"])
# plt.xlabel("cylinders")
# plt.ylabel("mpg")
plt.show()

# %%
# Distribution of displacement in the dataset
sns.histplot(data = df,x = df["displacement"] , kde = True)

# %%
# Relationship between "MPG" and "horsepower" and "Weight"
df["horsepower"] = df["horsepower"].astype

# %%
plt.figure(figsize = (5,3))
sns.scatterplot(data = df,x = df["mpg"] , y = df["acceleration"])
sns.regplot(data = df, x = df["mpg"] , y = df["acceleration"] , line_kws = {"color":"g"})

# %%
df.corr(method = 'CorrelationMethod' ,
min_periods =  df["mpg"],
numeric_only =  df["horsepower"])

# %%
# Checing for missing values 
hp_is_digit = pd.DataFrame(df["horsepower"].str.isdigit())
df[hp_is_digit["horsepower"] == False]

# %%
# Replacing them nwith np.nan
df = df.replace("?",np.nan)

# %%
#Checking whether there are missing values are there not
df[hp_is_digit["horsepower"] == False]

# %%
# Converting the type to float 64
df["horsepower"] = df["horsepower"].astype("float64")
df.drop(df["car name"],axis = 1 , inplace = True) # dropping categorical column
median_filler = lambda x :x .fillna(x.median()) # function applying the median to mid=ssing
df = df.apply(median_filler)

# %%
numerical_cols = df[["mpg","acceleration","weight","horsepower","displacement"]]
numerical_cols

# %%
sns.heatmap(numerical_cols.corr(), annot = True ,  cmap="coolwarm")

# %%
df.groupby("mpg")["model year"].count().sort_values(ascending = False).head(10)

# %%
 a = df[["mpg","acceleration"]]
sns.heatmap(a.corr(),annot = True , cmap = "coolwarm")

# %%
sns.boxplot(data = df , x = df["mpg"] , y = df["origin"])
plt.xlabel("mpg")
plt.ylabel("origin")
plt.show()

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.kdeplot(data = df,x = "body_mass_g",fill = True)
plt.axvline(3500,color = "m")

# %%
sns.kdeplot(data = df,x = "bill_length_mm" , color ="k")
plt.axvline(46.5, color = "m")

# %%
# we have drawn a histogram which includes density plot
# we can change the size of figure by figsize
# bins talks about how many bars can be included in this figure
# bins should be taken as "square root of the len(rows) in the dataset"
plt.figure(figsize = (6,4))
sns.histplot(data = df,x ="body_mass_g" , color = "m",
             edgecolor = "g",kde = True,bins =20)

# %%
df.describe()

# %%
df = sns.load_dataset("flights")
df

# %%
df.head()

# %%
plt.figure(figsize = (6,4))
sns.lineplot(x = df["month"] , y = df["passengers"],marker = "d")

# %%
plt.figure(figsize = (6,4))
sns.lineplot(x = df["month"] , y = df["passengers"],marker = "d",errorbar = None)

# %%
plt.figure(figsize = (6,4))
sns.lineplot(x = df["month"] , y = df["passengers"],marker = "d"
             ,hue = df["year"],errorbar = None,palette = "dark")

# %% [markdown]
# # 21/10/2024

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.pairplot(df[["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]])
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize = (10,6))
plt.subplot(1,2,1)
sns.kdeplot(x = df["bill_depth_mm"])
plt.subplot(1,2,2)
sns.violinplot(x = df["bill_depth_mm"] , inner = None) # Inner = None hides the boxplot
# Out:
# <Axes: xlabel='bill_depth_mm'>

# %%
# Creating violin plot for total feauture

sns.violinplot(x = df["bill_depth_mm"])
# Out:
# <Axes: xlabel='bill_depth_mm'>

# %%
plt.figure(figsize = (10,6))
plt.subplot(1,2,1)
sns.violinplot(y = df["bill_depth_mm"] , color = "g")
plt.subplot(1,2,2)
sns.violinplot(y = df["bill_depth_mm"],width = 0.4 , color ="m")
# If we want to rotate the violin plots put "y" in place of "x AXIS"
# Out:
# <Axes: ylabel='bill_depth_mm'>

# %%
# Horizonal Representation 
plt.figure(figsize = (10,4))
plt.subplot(2,1,1)
sns.boxplot(x = df["bill_depth_mm"] , color = "m")
plt.axvline(df["bill_depth_mm"].quantile(0.25))

plt.subplot(2,1,2)
sns.violinplot(x = df["bill_depth_mm"],color = "c",inner = "quartile") #inner="quartile" gives quARTILES
plt.axvline(df["bill_depth_mm"].quantile(0.25))

# %%
# cREATING the violin plot 
sns.violinplot(x = df["bill_depth_mm"] ,y = df["species"])

# %%
sns.boxplot(x = df["bill_depth_mm"] ,y = df["species"])

# %%
sns.violinplot(x = df["bill_depth_mm"] ,y = df["island"],hue = df["species"])

# %%
sns.violinplot(x = df["body_mass_g"] ,y = df["island"],hue = df["species"])

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.violinplot(penguin['bill_depth_mm'])
plt.subplot(1,2,2)
sns.violinplot(y=penguin['bill_depth_mm'],inner='boxplot',color='#FFECC8')
sns.violinplot(y=penguin['bill_depth_mm'],inner='boxplot',width=0.4,color='black')
sns.violinplot(y=penguin['bill_depth_mm'],inner='boxplot',width=0.2,color='pink')

# %%
# here split parametre shows the distribution of hue got category

# %%
plt.figure(figsize = (16,8))
sns.violinplot( x = df["body_mass_g"] ,hue = df["sex"],split = True)
# Out:
# <Axes: xlabel='body_mass_g'>

# %%
sns.__version__

# %%
plt.figure(figsize = (16,8))
sns.violinplot( x = df["body_mass_g"],y = df["species"] ,hue = df["sex"],split = True , inner = "quartile")

# %%
# CReate violin plot for flippers lengths across diffrent islands
# Create violin plot for flippers lengths across different species
# creat violin plot

# %%
sns.violinplot(x = df["flipper_length_mm"], hue = df["island"],split = True)
# Out:
# <Axes: xlabel='flipper_length_mm'>

# %%
sns.violinplot(x = df["flipper_length_mm"] , hue = df["species"],split = True)
# Out:
# <Axes: xlabel='flipper_length_mm'>

# %%
# !pip uninstall seaborn
# Out:
# ^C

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import seaborn
print(seaborn.__file__)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\__init__.py

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.12.2'

# %%
sns.violinplot(x = df["flipper_length_mm"],y = df["species"] , hue = df["sex"] ,inner = "quartile",split = True)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='species'>

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
pip install --upgrade seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 217.9 kB/s eta 0:00:02
#    ---- ---------------------------------- 30.7/294.9 kB 217.9 kB/s eta 0:00:02
#    -------- ------------------------------ 61.4/294.9 kB 272.3 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 272.3 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 272.3 kB/s eta 0:00:01
# ...
