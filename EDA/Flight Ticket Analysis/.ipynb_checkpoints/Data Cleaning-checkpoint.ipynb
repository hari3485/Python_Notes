# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv("final_holidays_data.csv", index_col = "Unnamed: 0")

# %%
data2 = pd.read_csv("final_holidays_data1.csv", index_col = "Unnamed: 0")

# %%
data3 = pd.read_csv("finals_weekends_weekdays.csv", index_col = "Unnamed: 0")

# %%
data4 = pd.read_csv("finals_weekends_weekdays1.csv", index_col = "Unnamed: 0")

# %%
data1
# Out:
#            Price    Airline Departure City Arrival City Travel Date Duration  \
# 0   INR29,384.18  Air India            DEL          BOM      25 Dec   2h 10m
# 1   INR29,382.40  Air India            DEL          BOM      25 Dec   2h 25m
# 2   INR37,417.30  Air India            DEL          BOM      25 Dec   2h 05m
# 3   INR29,384.18  Air India            DEL          BOM      25 Dec   2h 15m
# 4   INR29,384.18  Air India            DEL          BOM      25 Dec   2h 15m
# ..           ...        ...            ...          ...         ...      ...
# 62   INR7,049.26     IndiGo            CCU          GAU      26 Jan  22h 40m
# 63   INR7,369.52  Akasa Air            CCU          GAU      26 Jan  21h 50m
# 64  INR11,690.00     IndiGo            CCU          GAU      26 Jan  14h 25m
# 65   INR7,804.57  Air India            CCU          GAU      26 Jan  25h 50m
# 66  INR12,788.00     IndiGo            CCU          GAU      26 Jan  15h 10m
#
#               Stops Cabin Class
# ...

# %%
data2
# Out:
#             Price         Airline Departure City Arrival City Travel Date  \
# 0    INR64,173.64       Air India            DEL          BOM      25 Dec
# 1   INR257,611.94  Etihad Airways            DEL          BOM      25 Dec
# 2   INR240,354.01  Etihad Airways            DEL          BOM      25 Dec
# 3     INR9,451.24       Air India            DEL          BOM      25 Dec
# 4    INR11,702.96       Air India            DEL          BOM      25 Dec
# ..            ...             ...            ...          ...         ...
# 29   INR42,917.00       Air India            CCU          GAU      26 Jan
# 30   INR43,057.00       Air India            CCU          GAU      26 Jan
# 31   INR44,589.00       Air India            CCU          GAU      26 Jan
# 32   INR43,995.00       Air India            CCU          GAU      26 Jan
# 33   INR45,675.00       Air India            CCU          GAU      26 Jan
#
#    Duration            Stops      Cabin Class
# ...

# %%
data3
# Out:
#              Price    Airline Departure City Arrival City Travel Date  \
# 0     INR13,359.21  Air India            DEL          BOM      18 Dec
# 1      INR9,227.00  Air India            DEL          BOM      18 Dec
# 2     INR22,825.78  Air India            DEL          BOM      18 Dec
# 3     INR14,202.03     IndiGo            DEL          BOM      18 Dec
# 4     INR14,202.03     IndiGo            DEL          BOM      18 Dec
# ...            ...        ...            ...          ...         ...
# 1986   INR8,862.93  Akasa Air            CCU          GAU       9 Feb
# 1987   INR8,715.20     IndiGo            CCU          GAU       9 Feb
# 1988   INR7,414.09     IndiGo            CCU          GAU       9 Feb
# 1989   INR8,780.31     IndiGo            CCU          GAU       9 Feb
# 1990   INR9,698.30     IndiGo            CCU          GAU       9 Feb
#
#      Duration            Stops Cabin Class
# 0      2h 25m  Cheapest direct     Economy
# ...

# %%
data4
# Out:
#              Price    Airline Departure City Arrival City Travel Date  \
# 0     INR17,368.24  Air India            DEL          BOM      18 Dec
# 1     INR13,968.99  Air India            DEL          BOM      18 Dec
# 2     INR17,452.24  Air India            DEL          BOM      18 Dec
# 3     INR17,834.13  Air India            DEL          BOM      18 Dec
# 4     INR17,461.14  Air India            DEL          BOM      18 Dec
# ...            ...        ...            ...          ...         ...
# 1062  INR22,384.00  Air India            CCU          GAU       9 Feb
# 1063  INR19,497.00  Air India            CCU          GAU       9 Feb
# 1064  INR42,707.00  Air India            CCU          GAU       9 Feb
# 1065  INR42,203.00  Air India            CCU          GAU       9 Feb
# 1066  INR65,163.00  Air India            CCU          GAU       9 Feb
#
#      Duration            Stops      Cabin Class
# 0      2h 05m  Cheapest direct  Premium Economy
# ...

# %%
final_data = pd.concat([data1,data2,data3,data4],ignore_index=True)

# %%
final_data
# Out:
#              Price    Airline Departure City Arrival City Travel Date  \
# 0     INR29,384.18  Air India            DEL          BOM      25 Dec
# 1     INR29,382.40  Air India            DEL          BOM      25 Dec
# 2     INR37,417.30  Air India            DEL          BOM      25 Dec
# 3     INR29,384.18  Air India            DEL          BOM      25 Dec
# 4     INR29,384.18  Air India            DEL          BOM      25 Dec
# ...            ...        ...            ...          ...         ...
# 4433  INR22,384.00  Air India            CCU          GAU       9 Feb
# 4434  INR19,497.00  Air India            CCU          GAU       9 Feb
# 4435  INR42,707.00  Air India            CCU          GAU       9 Feb
# 4436  INR42,203.00  Air India            CCU          GAU       9 Feb
# 4437  INR65,163.00  Air India            CCU          GAU       9 Feb
#
#      Duration            Stops      Cabin Class
# 0      2h 10m           Direct         Business
# ...

# %%
final_data["Booking Date"] = "16 Dec"
final_data
# Out:
#              Price    Airline Departure City Arrival City Travel Date  \
# 0     INR29,384.18  Air India            DEL          BOM      25 Dec
# 1     INR29,382.40  Air India            DEL          BOM      25 Dec
# 2     INR37,417.30  Air India            DEL          BOM      25 Dec
# 3     INR29,384.18  Air India            DEL          BOM      25 Dec
# 4     INR29,384.18  Air India            DEL          BOM      25 Dec
# ...            ...        ...            ...          ...         ...
# 4433  INR22,384.00  Air India            CCU          GAU       9 Feb
# 4434  INR19,497.00  Air India            CCU          GAU       9 Feb
# 4435  INR42,707.00  Air India            CCU          GAU       9 Feb
# 4436  INR42,203.00  Air India            CCU          GAU       9 Feb
# 4437  INR65,163.00  Air India            CCU          GAU       9 Feb
#
#      Duration            Stops      Cabin Class Booking Date
# 0      2h 10m           Direct         Business       16 Dec
# ...

# %%
final_data.to_csv("Final Data.csv")

# %% [markdown]
# # Simple EDA

# %%
final_data.shape
# Out:
# (4438, 9)

# %%
final_data.isnull().sum()
# Out:
# Price             0
# Airline           0
# Departure City    0
# Arrival City      0
# Travel Date       0
# Duration          0
# Stops             0
# Cabin Class       0
# Booking Date      0
# dtype: int64

# %%
final_data.dtypes
# Out:
# Price             object
# Airline           object
# Departure City    object
# Arrival City      object
# Travel Date       object
# Duration          object
# Stops             object
# Cabin Class       object
# Booking Date      object
# dtype: object

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4438 entries, 0 to 4437
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Price           4438 non-null   object
#  1   Airline         4438 non-null   object
#  2   Departure City  4438 non-null   object
#  3   Arrival City    4438 non-null   object
#  4   Travel Date     4438 non-null   object
#  5   Duration        4438 non-null   object
#  6   Stops           4438 non-null   object
#  7   Cabin Class     4438 non-null   object
#  8   Booking Date    4438 non-null   object
# dtypes: object(9)
# memory usage: 312.2+ KB

# %%
final_data[final_data.duplicated()]
# Out:
#              Price    Airline Departure City Arrival City Travel Date  \
# 4     INR29,384.18  Air India            DEL          BOM      25 Dec
# 9     INR37,423.53  Air India            DEL          BOM      25 Dec
# 10    INR37,423.53  Air India            DEL          BOM      25 Dec
# 11    INR37,423.53  Air India            DEL          BOM      25 Dec
# 12    INR37,423.53  Air India            DEL          BOM      25 Dec
# ...            ...        ...            ...          ...         ...
# 4231  INR17,033.92  Air India            DEL          BLR       4 Jan
# 4259  INR10,341.99  Air India            DEL          BLR       8 Feb
# 4260  INR10,341.99  Air India            DEL          BLR       8 Feb
# 4267  INR11,144.69  Air India            DEL          BLR       8 Feb
# 4276  INR11,639.87  Air India            DEL          BLR       9 Feb
#
#      Duration   Stops      Cabin Class Booking Date
# 4      2h 15m  Direct         Business       16 Dec
# ...

# %% [markdown]
# # DATA CLEANING

# %%
final_data = final_data.copy()

# %% [markdown]
# #### Dropping Duplicates

# %%
final_data = final_data.drop_duplicates(ignore_index = True)

# %%
final_data
# Out:
#              Price    Airline Departure City Arrival City Travel Date  \
# 0     INR29,384.18  Air India            DEL          BOM      25 Dec
# 1     INR29,382.40  Air India            DEL          BOM      25 Dec
# 2     INR37,417.30  Air India            DEL          BOM      25 Dec
# 3     INR29,384.18  Air India            DEL          BOM      25 Dec
# 4     INR29,382.40  Air India            DEL          BOM      25 Dec
# ...            ...        ...            ...          ...         ...
# 3887  INR22,384.00  Air India            CCU          GAU       9 Feb
# 3888  INR19,497.00  Air India            CCU          GAU       9 Feb
# 3889  INR42,707.00  Air India            CCU          GAU       9 Feb
# 3890  INR42,203.00  Air India            CCU          GAU       9 Feb
# 3891  INR65,163.00  Air India            CCU          GAU       9 Feb
#
#      Duration            Stops      Cabin Class Booking Date
# 0      2h 10m           Direct         Business       16 Dec
# ...

# %%
final_data.columns = ['price', 'airline_name', 'departure_city', 'arrival_city', 'travel_date','duration', 'stops', 'cabin_class', 'booking_date']

# %%
final_data
# Out:
#              price airline_name departure_city arrival_city travel_date  \
# 0     INR29,384.18    Air India            DEL          BOM      25 Dec
# 1     INR29,382.40    Air India            DEL          BOM      25 Dec
# 2     INR37,417.30    Air India            DEL          BOM      25 Dec
# 3     INR29,384.18    Air India            DEL          BOM      25 Dec
# 4     INR29,382.40    Air India            DEL          BOM      25 Dec
# ...            ...          ...            ...          ...         ...
# 3887  INR22,384.00    Air India            CCU          GAU       9 Feb
# 3888  INR19,497.00    Air India            CCU          GAU       9 Feb
# 3889  INR42,707.00    Air India            CCU          GAU       9 Feb
# 3890  INR42,203.00    Air India            CCU          GAU       9 Feb
# 3891  INR65,163.00    Air India            CCU          GAU       9 Feb
#
#      duration            stops      cabin_class booking_date
# ...

# %% [markdown]
# #### Price column cleaning

# %%
final_data["price"]
# Out:
# 0       INR29,384.18
# 1       INR29,382.40
# 2       INR37,417.30
# 3       INR29,384.18
# 4       INR29,382.40
#             ...
# 3887    INR22,384.00
# 3888    INR19,497.00
# 3889    INR42,707.00
# 3890    INR42,203.00
# 3891    INR65,163.00
# Name: price, Length: 3892, dtype: object

# %%
final_data["price"] = final_data["price"].str.replace("INR","")

# %%
final_data["price"] = final_data["price"].str.replace(",","")

# %%
final_data["price"] = final_data["price"].astype(float)

# %%
final_data["price"]
# Out:
# 0       29384.18
# 1       29382.40
# 2       37417.30
# 3       29384.18
# 4       29382.40
#           ...
# 3887    22384.00
# 3888    19497.00
# 3889    42707.00
# 3890    42203.00
# 3891    65163.00
# Name: price, Length: 3892, dtype: float64

# %% [markdown]
# #### depature city column cleaning

# %%
final_data["departure_city"].unique()
# Out:
# array(['DEL', 'BLR', 'MAA', 'BOM', 'CCU'], dtype=object)

# %%
final_data["departure_city"] = final_data["departure_city"].str.replace("DEL","Delhi").str.replace("CCU","Kolkata").str.replace("BLR","Banglore").str.replace("BOM","Mumbai").str.replace("MAA","Chennai")

# %%
final_data["departure_city"]
# Out:
# 0         Delhi
# 1         Delhi
# 2         Delhi
# 3         Delhi
# 4         Delhi
#          ...
# 3887    Kolkata
# 3888    Kolkata
# 3889    Kolkata
# 3890    Kolkata
# 3891    Kolkata
# Name: departure_city, Length: 3892, dtype: object

# %%
final_data["departure_city"].unique()
# Out:
# array(['Delhi', 'Banglore', 'Chennai', 'Mumbai', 'Kolkata'], dtype=object)

# %% [markdown]
# #### Arrival city column cleaning

# %%
final_data["arrival_city"].unique()
# Out:
# array(['BOM', 'CCU', 'HYD', 'GOX', 'BLR', 'GAU'], dtype=object)

# %%
final_data["arrival_city"] = final_data["arrival_city"].str.replace("HYD","Hyderabad").str.replace("CCU","Kolkata").str.replace("BLR","Banglore").str.replace("BOM","Mumbai").str.replace("GAU","Guwahathi").str.replace("GOX","Goa")

# %%
final_data["arrival_city"]
# Out:
# 0          Mumbai
# 1          Mumbai
# 2          Mumbai
# 3          Mumbai
# 4          Mumbai
#           ...
# 3887    Guwahathi
# 3888    Guwahathi
# 3889    Guwahathi
# 3890    Guwahathi
# 3891    Guwahathi
# Name: arrival_city, Length: 3892, dtype: object

# %%
final_data["arrival_city"].unique()
# Out:
# array(['Mumbai', 'Kolkata', 'Hyderabad', 'Goa', 'Banglore', 'Guwahathi'],
#       dtype=object)

# %% [markdown]
# #### travel date cleaning

# %%
final_data["travel_date"]
# Out:
# 0       25 Dec
# 1       25 Dec
# 2       25 Dec
# 3       25 Dec
# 4       25 Dec
#          ...
# 3887     9 Feb
# 3888     9 Feb
# 3889     9 Feb
# 3890     9 Feb
# 3891     9 Feb
# Name: travel_date, Length: 3892, dtype: object

# %%
def add_year(travel_date):
    month = pd.to_datetime(travel_date, format = "%d %b").month
    if month == 12:
        return f"{travel_date} 2024"
    else:
        return f"{travel_date} 2025"

# %%
final_data["travel_date"] = final_data["travel_date"].apply(add_year)

# %%
final_data["travel_date"] = pd.to_datetime(final_data["travel_date"])
final_data["travel_date"]
# Out:
# 0      2024-12-25
# 1      2024-12-25
# 2      2024-12-25
# 3      2024-12-25
# 4      2024-12-25
#           ...
# 3887   2025-02-09
# 3888   2025-02-09
# 3889   2025-02-09
# 3890   2025-02-09
# 3891   2025-02-09
# Name: travel_date, Length: 3892, dtype: datetime64[ns]

# %%
final_data
# Out:
#          price airline_name departure_city arrival_city travel_date duration  \
# 0     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 10m
# 1     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# 2     37417.30    Air India          Delhi       Mumbai  2024-12-25   2h 05m
# 3     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 15m
# 4     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# ...        ...          ...            ...          ...         ...      ...
# 3887  22384.00    Air India        Kolkata    Guwahathi  2025-02-09  20h 20m
# 3888  19497.00    Air India        Kolkata    Guwahathi  2025-02-09  25h 45m
# 3889  42707.00    Air India        Kolkata    Guwahathi  2025-02-09      11h
# 3890  42203.00    Air India        Kolkata    Guwahathi  2025-02-09  12h 55m
# 3891  65163.00    Air India        Kolkata    Guwahathi  2025-02-09  10h 25m
#
# ...

# %% [markdown]
# #### Booking Date cleaning

# %%
final_data["booking_date"] = final_data["booking_date"].apply(add_year)

# %%
final_data["booking_date"] = pd.to_datetime(final_data["booking_date"])
final_data["booking_date"]
# Out:
# 0      2024-12-16
# 1      2024-12-16
# 2      2024-12-16
# 3      2024-12-16
# 4      2024-12-16
#           ...
# 3887   2024-12-16
# 3888   2024-12-16
# 3889   2024-12-16
# 3890   2024-12-16
# 3891   2024-12-16
# Name: booking_date, Length: 3892, dtype: datetime64[ns]

# %%
final_data
# Out:
#          price airline_name departure_city arrival_city travel_date duration  \
# 0     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 10m
# 1     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# 2     37417.30    Air India          Delhi       Mumbai  2024-12-25   2h 05m
# 3     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 15m
# 4     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# ...        ...          ...            ...          ...         ...      ...
# 3887  22384.00    Air India        Kolkata    Guwahathi  2025-02-09  20h 20m
# 3888  19497.00    Air India        Kolkata    Guwahathi  2025-02-09  25h 45m
# 3889  42707.00    Air India        Kolkata    Guwahathi  2025-02-09      11h
# 3890  42203.00    Air India        Kolkata    Guwahathi  2025-02-09  12h 55m
# 3891  65163.00    Air India        Kolkata    Guwahathi  2025-02-09  10h 25m
#
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3892 entries, 0 to 3891
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           3892 non-null   float64
#  1   airline_name    3892 non-null   object
#  2   departure_city  3892 non-null   object
#  3   arrival_city    3892 non-null   object
#  4   travel_date     3892 non-null   datetime64[ns]
#  5   duration        3892 non-null   object
#  6   stops           3892 non-null   object
#  7   cabin_class     3892 non-null   object
#  8   booking_date    3892 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(6)
# memory usage: 273.8+ KB

# %% [markdown]
# ### Calculating difference between travel_date and booking_date

# %%
final_data["days_until_travel"] = (final_data["travel_date"] - final_data["booking_date"]).dt.days

# %% [markdown]
# final_data

# %%
def booking_type(days_until_travel):
    if days_until_travel <= 7:
        return "Last-minute" 
    elif days_until_travel > 7 and days_until_travel <=30:
        return "Moderate"
    else:
        return "Advanced"

# %%
final_data["booking_type"] = final_data["days_until_travel"].apply(booking_type)

# %%
final_data
# Out:
#          price airline_name departure_city arrival_city travel_date duration  \
# 0     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 10m
# 1     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# 2     37417.30    Air India          Delhi       Mumbai  2024-12-25   2h 05m
# 3     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 15m
# 4     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# ...        ...          ...            ...          ...         ...      ...
# 3887  22384.00    Air India        Kolkata    Guwahathi  2025-02-09  20h 20m
# 3888  19497.00    Air India        Kolkata    Guwahathi  2025-02-09  25h 45m
# 3889  42707.00    Air India        Kolkata    Guwahathi  2025-02-09      11h
# 3890  42203.00    Air India        Kolkata    Guwahathi  2025-02-09  12h 55m
# 3891  65163.00    Air India        Kolkata    Guwahathi  2025-02-09  10h 25m
#
# ...

# %%
holidays = ['2024-12-25', '2025-01-01', '2025-01-26']
holidays = pd.to_datetime(holidays)
def travel_type(travel_date):
    if travel_date in holidays:
        return 'Holiday'
    elif travel_date.weekday() >= 5:
        return 'Weekend'
    else:
        return 'Weekday'

# %%
final_data["travel_type"] = final_data["travel_date"].apply(travel_type)

# %%
final_data
# Out:
#          price airline_name departure_city arrival_city travel_date duration  \
# 0     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 10m
# 1     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# 2     37417.30    Air India          Delhi       Mumbai  2024-12-25   2h 05m
# 3     29384.18    Air India          Delhi       Mumbai  2024-12-25   2h 15m
# 4     29382.40    Air India          Delhi       Mumbai  2024-12-25   2h 25m
# ...        ...          ...            ...          ...         ...      ...
# 3887  22384.00    Air India        Kolkata    Guwahathi  2025-02-09  20h 20m
# 3888  19497.00    Air India        Kolkata    Guwahathi  2025-02-09  25h 45m
# 3889  42707.00    Air India        Kolkata    Guwahathi  2025-02-09      11h
# 3890  42203.00    Air India        Kolkata    Guwahathi  2025-02-09  12h 55m
# 3891  65163.00    Air India        Kolkata    Guwahathi  2025-02-09  10h 25m
#
# ...

# %% [markdown]
# #### Duration column cleaning

# %%
final_data["duration"]
# Out:
# 0        2h 10m
# 1        2h 25m
# 2        2h 05m
# 3        2h 15m
# 4        2h 25m
#          ...
# 3887    20h 20m
# 3888    25h 45m
# 3889        11h
# 3890    12h 55m
# 3891    10h 25m
# Name: duration, Length: 3892, dtype: object

# %%
def convert_to_minutes(duration):
    hours = int(duration.split('h')[0]) if 'h' in duration else 0
    minutes = int(duration.split('h')[-1].replace('m', '').strip()) if 'm' in duration else 0
    return hours * 60 + minutes

# %%
final_data["duration"] = final_data["duration"].apply(convert_to_minutes)

# %%
final_data["duration"].astype(int)
# Out:
# 0        130
# 1        145
# 2        125
# 3        135
# 4        145
#         ...
# 3887    1220
# 3888    1545
# 3889     660
# 3890     775
# 3891     625
# Name: duration, Length: 3892, dtype: int32

# %%
final_data
# Out:
#          price airline_name departure_city arrival_city travel_date  duration  \
# 0     29384.18    Air India          Delhi       Mumbai  2024-12-25       130
# 1     29382.40    Air India          Delhi       Mumbai  2024-12-25       145
# 2     37417.30    Air India          Delhi       Mumbai  2024-12-25       125
# 3     29384.18    Air India          Delhi       Mumbai  2024-12-25       135
# 4     29382.40    Air India          Delhi       Mumbai  2024-12-25       145
# ...        ...          ...            ...          ...         ...       ...
# 3887  22384.00    Air India        Kolkata    Guwahathi  2025-02-09      1220
# 3888  19497.00    Air India        Kolkata    Guwahathi  2025-02-09      1545
# 3889  42707.00    Air India        Kolkata    Guwahathi  2025-02-09       660
# 3890  42203.00    Air India        Kolkata    Guwahathi  2025-02-09       775
# 3891  65163.00    Air India        Kolkata    Guwahathi  2025-02-09       625
#
# ...

# %%
final_data["cabin_class"].unique()
# Out:
# array(['Business', 'Economy', 'First', 'Premium Economy'], dtype=object)

# %%
final_data["stops"] = final_data["stops"].str.replace('Cheapest direct','Direct')

# %%
final_data
# Out:
#          price airline_name departure_city arrival_city travel_date  duration  \
# 0     29384.18    Air India          Delhi       Mumbai  2024-12-25       130
# 1     29382.40    Air India          Delhi       Mumbai  2024-12-25       145
# 2     37417.30    Air India          Delhi       Mumbai  2024-12-25       125
# 3     29384.18    Air India          Delhi       Mumbai  2024-12-25       135
# 4     29382.40    Air India          Delhi       Mumbai  2024-12-25       145
# ...        ...          ...            ...          ...         ...       ...
# 3887  22384.00    Air India        Kolkata    Guwahathi  2025-02-09      1220
# 3888  19497.00    Air India        Kolkata    Guwahathi  2025-02-09      1545
# 3889  42707.00    Air India        Kolkata    Guwahathi  2025-02-09       660
# 3890  42203.00    Air India        Kolkata    Guwahathi  2025-02-09       775
# 3891  65163.00    Air India        Kolkata    Guwahathi  2025-02-09       625
#
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3892 entries, 0 to 3891
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price              3892 non-null   float64
#  1   airline_name       3892 non-null   object
#  2   departure_city     3892 non-null   object
#  3   arrival_city       3892 non-null   object
#  4   travel_date        3892 non-null   datetime64[ns]
#  5   duration           3892 non-null   int64
#  6   stops              3892 non-null   object
#  7   cabin_class        3892 non-null   object
#  8   booking_date       3892 non-null   datetime64[ns]
#  9   days_until_travel  3892 non-null   int64
#  10  booking_type       3892 non-null   object
#  11  travel_type        3892 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(7)
# memory usage: 365.0+ KB

# %%
final_data.to_csv("Cleaned Data.csv")

# %%
final_data.describe(include="number")
# Out:
#                price     duration  days_until_travel
# count    3892.000000  3892.000000        3892.000000
# mean    30434.573099   425.412384          24.342497
# std     29713.645818   362.888379          18.421048
# min      2682.000000    70.000000           2.000000
# 25%     10554.100000   155.000000           9.000000
# 50%     19105.110000   345.000000          19.000000
# 75%     40541.565000   525.000000          41.000000
# max    291560.990000  1750.000000          55.000000
