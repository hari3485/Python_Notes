# %% [markdown]
# **Types Of variables and methods**

# %% [markdown]
# Instance variables
#
# Static Variables (class variables)

# %% [markdown]
# In Python, a static variable is a variable that is shared among all instances of a class, rather than being unique to each instance. It is also sometimes referred to as a class variable, because it belongs to the class itself rather than any particular instance of the class.
#
# Static variables are defined inside the class definition, but outside of any method definitions. They are typically initialized with a value, just like an instance variable, but they can be accessed and modified through the class itself, rather than through an instance.

# %% [markdown]
# **Instance Variables** are those attributes that are not shared by objects. Every object has its own copy of the instance attribute i.e. for every object, instance attribute is different.
#
# Within the class by using self and object reference.

# %% [markdown]
# **Using Self and object reference**

# %%
#defualt cocnstructor
class Employee:

    def display(self):
        print('Inside Display')

emp = Employee()
emp.display()

emp1=Employee()
emp1.display()
# Out:
# Inside Display
# Inside Display

# %%
#non parametrised cocnstructor
class Employee:
    def __init__(self):
        print("Inside display")

emp = Employee()
emp1=Employee()
# Out:
# Inside display
# Inside display

# %%
#parametrised cocnstructor
class Employee:
    def __init__(self,name,gender):
        print("Inside display")

emp = Employee("ramya","f")
emp1= Employee("ram","m")
# Out:
# Inside display
# Inside display

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#creating class
class Employee:
     
    # constructor
    def __init__(self, name, eid): #paramterized constructor
         
        # instance variable
        self.name = name
        self.eid = eid
      
    def display(self):
         
        # using self to access
        # variable inside class
        print("hello my name is:", self.name)
        print("my roll number is:", self.eid)
         
e1= Employee("ramya",100)
print(e1.name)

e2=Employee("ram",102)
print(e2.name)
# Out:
# ramya
# ram

# %%
Employee.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 Employee.name
#
# AttributeError: type object 'Employee' has no attribute 'name'

# %%
Employee.name="temporary"

# %%
Employee.name
# Out:
# 'temporary'

# %%
e1.name
# Out:
# 'ramya'

# %%
e2.name
# Out:
# 'ram'

# %%
s1.given_name="ankit"

# %%
s1.display()
# Out:
# hello my name is: ankit
# my roll number is: 200

# %%
#creating class
class Employee:
     
    office_name = "innomatics"
    def __init__(self, name, eid): #paramterized constructor
         
        # instance variable
        self.name = name
        self.eid = eid
      
    def display(self):
         
        # using self to access
        # variable inside class
        print("hello my name is:", self.name)
        print("my roll number is:", self.eid)
         
e1= Employee("ramya",100)
print(e1.name)

e2=Employee("ram",102)
print(e2.name)

e3=Employee("abhi",103)
print(e3.name)
# Out:
# ramya
# ram
# abhi

# %%
print(e1.office_name)
print(e2.office_name)
print(e3.office_name)
# Out:
# innomatics
# innomatics
# innomatics

# %%
#class variable/static variable we are changing 
#throuugh class name
Employee.office_name ="Zeominds"

# %%
print(e1.office_name)
print(e2.office_name)
print(e3.office_name)
# Out:
# Zeominds
# Zeominds
# Zeominds

# %%
##class variable/static variable we are changing 
#throuugh objects

e1.office_name = "google"

# %%
print(e1.office_name)
# Out:
# google

# %%
print(e2.office_name)
print(e3.office_name)
# Out:
# Zeominds
# Zeominds

# %%
Employee.office_name = "Innomatics pvt solution lmtd"

# %%
print(e1.office_name) #
print(e2.office_name)
print(e3.office_name)
# Out:
# google
# Innomatics pvt solution lmtd
# Innomatics pvt solution lmtd

# %%
e1.office_name ="facebook"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 Employee.e1.office_name ="facebook"
#
# AttributeError: type object 'Employee' has no attribute 'e1'

# %% [markdown]
# **Static Variables/class variables:**

# %% [markdown]
# static/class var can be accessed using objects as well as class names
# but instance variables can be accessed using only objects.

# %%
class College:
    college_name= "Hyderabad central university" #class/static variable
    
    def __init__(self,name,gender): #instance variables
        self.name=name
        self.gender=gender
        
    def display_student_name(self):
        print(self.name)
        
    def display_college_name(self):
        print(self.college_name)

# %%
s1=College("sandeep","male")
print(s1.name,s1.gender)

s2=College("shruthi","female")
print(s2.name,s2.gender)

s3=College("ramya","female")
print(s3.name,s3.gender)
# Out:
# sandeep male
# shruthi female
# ramya female

# %%
College.college_name
# Out:
# 'Hyderabad central university'

# %%
College.college_name = "UOH"

# %%
print(s1.college_name)
print(s2.college_name)
print(s3.college_name)
# Out:
# UOH
# UOH
# UOH

# %%
s1.college_name
# Out:
# 'UOH'

# %%
s1.college_name = "BITS"

# %%
print(s1.college_name)
print(s2.college_name)
print(s3.college_name)
# Out:
# BITS
# UOH
# UOH

# %%
College.college_name = "VNR"

# %%
print(s1.college_name)
print(s2.college_name)
print(s3.college_name)
# Out:
# BITS
# VNR
# VNR

# %%
dir(s1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'college_name',
#  'display_college_name',
#  'display_student_name',
#  'gender',
#  'name']

# %%
dir(s2)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'college_name',
#  'display_college_name',
#  'display_student_name',
#  'gender',
#  'name']
