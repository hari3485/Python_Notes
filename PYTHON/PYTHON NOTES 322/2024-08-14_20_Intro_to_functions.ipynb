# %% [markdown]
# # Today's Agenda
#
# > ### What is function?
# > ### What are the advantages of functions?
# > ### How to create our own functions?
# > ### How to use conditional statements and loops in functions?
# > ### What is Ananymous function?
# > ### What is lambda expressions?
# > ### what are the different other functions available in python?

# %% [markdown]
# ## What is function?
# - Function is a group of statements that performs a specific task.
# - A function is a collection of statements grouped together that performs an operation. When you call the *random.randint(a, b)* function, for example, the system actually executes the statements in the function and returns the result.

# %% [markdown]
# ## Advantages of Functions:
#
# - Makes your code more organized and manageable.
# - Brings resuability there by avoiding code redundency.

# %% [markdown]
# ### Some of terminalogies / keywords used in functions
#
# - **`def`** - Marks the start of the function header.
# - **`function name`** - used to uniquely identify the function. Function naming follows the same check list which we followed for variables.
# - **`Params/Args`** - used to pass values to a function. Params are optional.
# - **`Colon (:)`**- marks the end of the function header.
# - **`Doc String`** - A short description about the function.This is optional.
# - **`Business logic/Statements`** - One ore more valid Python statements to perform the required task.
# - **`return`** - This is optional. But this statement will help you to return a value from the function.
# - **`print`** - To dispaly the value from the function. This is optional.
# Either print or return need to be included at the end of the function.
# Make sure proper indentation is given inside the function body.

# %% [markdown]
# ```python
# def some_function_name(parameter1, parameter2.....):
#     '''This is the sample DOC STRING... Describes the work of the function...'''
#     IMPLEMENTATION LOGIC....
#     ......
#     ......
#     return/print()
# ```

# %% [markdown]
# ## Two important activities: Defining and invoking a function
#
# ![image.png](image.png)

# %% [markdown]
# ## defining the function

# %%
#### Larger/Greater number check

# %%
def larger_of_2_nos(num1, num2):
    '''This give the larger of the 2 given numbers'''
    if num1 > num2:
        print(f"Greater number between {num1} and {num2} is {num1}")
    elif num1 < num2:
        print(f"Greater number between {num1} and {num2} is {num2}")
    else:
        print("Both are same")

# %% [markdown]
# ## invoking/ calling the created function

# %%
#### check greater of the 2 number

# %%
larger_of_2_nos(12,12)
larger_of_2_nos(32,12)
type(larger_of_2_nos(12,52))
# Out:
# Both are same
# Greater number between 32 and 12 is 32
# Greater number between 12 and 52 is 52
# NoneType

# %%
def larger_of_2_nos(num1, num2):
    '''This give the larger of the 2 given numbers'''
    if num1 > num2:
        print(num1)
    elif num1 < num2:
        print(num2)
    else:
        print("Both are same")

# %%
larger_of_2_nos(12,12)
larger_of_2_nos(32,12)
type(larger_of_2_nos(12,52))
larger_of_2_nos(12,52) + 43 #### not possible because of PRINT statement as OUTPUT is not a VALUE
# Out:
# Both are same
# 32
# 52
# 52
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 larger_of_2_nos(32,12)
#       3 type(larger_of_2_nos(12,52))
# ----> 4 larger_of_2_nos(12,52) + 43
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# ### the <u><b>Random</b></u> module

# %%
### function --- randint

# %%
import random

# %%
random.randint(4,67)
# Out:
# 65

# %%
### function --- random

# %%
for index in range(100):
    print(random.randint(4,67000) * random.random())
# Out:
# 20472.254742673413
# 2562.8680704119292
# 37905.561473866735
# 266.2607472422222
# 550.3942232311268
# 29969.57849076762
# 18352.12433147376
# 25532.87985185685
# 4467.491314691459
# 6905.355164401738
# 28320.62660091863
# 6507.062259042475
# 24064.59288808031
# 11742.843384283995
# 19601.403605115564
# 33961.178323794884
# 3865.096077198652
# 9449.254177740664
# 25652.460136953476
# 47290.744481915215
# 5411.365906885276
# 38372.86358265145
# 47877.683300666125
# 3625.5752667733204
# 15705.699299927199
# 10951.968085817767
# 6774.9175967210285
# 39821.677395744606
# 388.69000107574595
# 25576.747863126715
# 20205.120769027162
# 12534.770849475028
# 14130.303345105527
# 747.1135822869837
# 4723.927359070013
# 1059.1410363963614
# 11017.8056556086
# 1307.9935834954636
# 10167.185974062157
# 1415.8957563762747
# 4886.533210361959
# 1249.0418833299652
# 1359.925780072309
# 929.7834686539117
# 768.3387146236996
# 19461.800360654735
# 256.8714164218244
# 13460.012264144638
# ...

# %% [markdown]
# ### Function definition
# - A function contains a header and body. The header begins with the def keyword, followed by the function’s name and parameters, and ends with a colon.

# %% [markdown]
# #### <u><b>Prime Number</u></b> check function

# %% [markdown]
# #### <u><b>NORMAL PROGRAM</u></b>

# %%
# %%time
import time
given_number = 137
flag = False
for factor in range(2,given_number):
    print("Checking FACTOR: ", factor)
    if given_number % factor == 0:
        flag = True
        break
    time.sleep(0.1)
if flag == False:
    print(f"{given_number} is a PRIME Number.")
else:
    print(f"{given_number} is NOT a PRIME Number/ COMPOSITE...")
# Out:
# Checking FACTOR:  2
# Checking FACTOR:  3
# Checking FACTOR:  4
# Checking FACTOR:  5
# Checking FACTOR:  6
# Checking FACTOR:  7
# Checking FACTOR:  8
# Checking FACTOR:  9
# Checking FACTOR:  10
# Checking FACTOR:  11
# Checking FACTOR:  12
# Checking FACTOR:  13
# Checking FACTOR:  14
# Checking FACTOR:  15
# Checking FACTOR:  16
# Checking FACTOR:  17
# Checking FACTOR:  18
# Checking FACTOR:  19
# Checking FACTOR:  20
# Checking FACTOR:  21
# Checking FACTOR:  22
# Checking FACTOR:  23
# Checking FACTOR:  24
# Checking FACTOR:  25
# Checking FACTOR:  26
# Checking FACTOR:  27
# Checking FACTOR:  28
# Checking FACTOR:  29
# Checking FACTOR:  30
# Checking FACTOR:  31
# Checking FACTOR:  32
# Checking FACTOR:  33
# Checking FACTOR:  34
# Checking FACTOR:  35
# Checking FACTOR:  36
# Checking FACTOR:  37
# Checking FACTOR:  38
# Checking FACTOR:  39
# Checking FACTOR:  40
# Checking FACTOR:  41
# Checking FACTOR:  42
# Checking FACTOR:  43
# Checking FACTOR:  44
# ...

# %% [markdown]
# #### <U><B>USING FUNCTION</B></U>

# %% [markdown]
# ##### <i><b><u>Defining</b></u> the Function</i>

# %%
def prime_no_check(given_number):
    flag = False
    for factor in range(2,given_number):
        if given_number % factor == 0:
            flag = True
            break
    if flag == False:
        print(f"{given_number} is a PRIME Number.")
    else:
        print(f"{given_number} is NOT a PRIME Number/ COMPOSITE...")

# %% [markdown]
# ##### <i><b><u>Calling/ Invoking</b></u> the Function</i>

# %%
prime_no_check(45)
# Out:
# 45 is NOT a PRIME Number/ COMPOSITE...

# %%
prime_no_check(67)
# Out:
# 67 is a PRIME Number.

# %% [markdown]
# ### FIND FACTORS OF THE NUMBER

# %%
# %%time
import time
given_number = 1000
list_of_factors = []
flag = False
for factor_check in range(2, given_number):
    print("The current check number: ", factor_check)
    if given_number % factor_check == 0:
        flag = True
        list_of_factors.append(factor_check)
    time.sleep(0.01)
if flag == True:
    print(f"Apart from '1' and '{given_number}' the factors are: ", list_of_factors)
else:
    print(f"The Number {given_number} is PRIME with factors as '1' and '{given_number}'")
# Out:
# The current check number:  2
# The current check number:  3
# The current check number:  4
# The current check number:  5
# The current check number:  6
# The current check number:  7
# The current check number:  8
# The current check number:  9
# The current check number:  10
# The current check number:  11
# The current check number:  12
# The current check number:  13
# The current check number:  14
# The current check number:  15
# The current check number:  16
# The current check number:  17
# The current check number:  18
# The current check number:  19
# The current check number:  20
# The current check number:  21
# The current check number:  22
# The current check number:  23
# The current check number:  24
# The current check number:  25
# The current check number:  26
# The current check number:  27
# The current check number:  28
# The current check number:  29
# The current check number:  30
# The current check number:  31
# The current check number:  32
# ...

# %%
# %%time
import time
given_number = 1000
list_of_factors = []
flag = False
for factor_check in range(2, (int(given_number/2) + 1)):
    print("The current check number: ", factor_check)
    if given_number % factor_check == 0:
        flag = True
        list_of_factors.append(factor_check)
    time.sleep(0.01)
if flag == True:
    print(f"Apart from '1' and '{given_number}' the factors are: ", list_of_factors)
else:
    print(f"The Number {given_number} is PRIME with factors as '1' and '{given_number}'")
# Out:
# The current check number:  2
# The current check number:  3
# The current check number:  4
# The current check number:  5
# The current check number:  6
# The current check number:  7
# The current check number:  8
# The current check number:  9
# The current check number:  10
# The current check number:  11
# The current check number:  12
# The current check number:  13
# The current check number:  14
# The current check number:  15
# The current check number:  16
# The current check number:  17
# The current check number:  18
# The current check number:  19
# The current check number:  20
# The current check number:  21
# The current check number:  22
# The current check number:  23
# The current check number:  24
# The current check number:  25
# The current check number:  26
# The current check number:  27
# The current check number:  28
# The current check number:  29
# The current check number:  30
# The current check number:  31
# The current check number:  32
# ...

# %% [markdown]
# ### The <b><u>Math</b></u> module

# %%
import math

# %%
# %%time
import time
given_number = 1000
list_of_factors = []
flag = False
for factor_check in range(2, (int(math.sqrt(given_number)) + 1)):
    print("The current check number: ", factor_check)
    if given_number % factor_check == 0:
        flag = True
        list_of_factors.append(factor_check)
        list_of_factors.append(int(given_number/factor_check))
    time.sleep(0.01)
if flag == True:
    print(f"Apart from '1' and '{given_number}' the factors are: ", sorted(list_of_factors))
else:
    print(f"The Number {given_number} is PRIME with factors as '1' and '{given_number}'")
# Out:
# The current check number:  2
# The current check number:  3
# The current check number:  4
# The current check number:  5
# The current check number:  6
# The current check number:  7
# The current check number:  8
# The current check number:  9
# The current check number:  10
# The current check number:  11
# The current check number:  12
# The current check number:  13
# The current check number:  14
# The current check number:  15
# The current check number:  16
# The current check number:  17
# The current check number:  18
# The current check number:  19
# The current check number:  20
# The current check number:  21
# The current check number:  22
# The current check number:  23
# The current check number:  24
# The current check number:  25
# The current check number:  26
# The current check number:  27
# The current check number:  28
# The current check number:  29
# The current check number:  30
# The current check number:  31
# ...
